# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\sumona\anaconda3\lib\site-packages (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sumona\anaconda3\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sumona\anaconda3\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\sumona\anaconda3\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\sumona\anaconda3\lib\site-packages (from requests) (2.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\sumona\anaconda3\lib\site-packages (1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: webencodings in c:\users\sumona\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\sumona\anaconda3\lib\site-packages (from html5lib) (1.15.0)

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\sumona\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sumona\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sumona\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
URL = "https://www.shine.com/"
r = requests.get(URL)
print(r.content)
# Out:
# b'\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <title>Jobs 2022 - Search Jobs in India, Latest Job Vacancies, Recruitment - Shine.com</title>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n    <meta http-equiv="content-language" content="en-us" />\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1" />\n    <meta property="fb:app_id" content="87369453667" />\n    <meta property="og:site_name" content="Shine" />\n    <meta property="og:type" content="company" />\n    <meta property="og:image" content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" />\n    <meta itemprop="image" content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" />\n    <link rel="SHORTCUT ICON" href="https://static1.shine.com/c/s1/images/favicon.ico" />\n    <link rel="search" href="https://www.shine.com/search.xml" type="application/opensearchdescription+xml"\n        title="jobs on Shine.com" />\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta name="description"\n        content="Shine.com is India\'s Leading Online Job and Recruitment Portal - Search &amp; Apply for Latest Job Vacancies across Top Companies in India. Register FREE Now!" />\n    <meta property="og:title" content="Shine.com : One Stop Destination To Find Your Dream Job on the Go" />\n    <meta name="keywords"\n        content="job, jobs, job in india, job search, job vacancies, job openings, find jobs, shine, jobs for freshers, apply jobs" />\n    <meta property="og:url" content="https://www.shine.com/" />\n    <meta property="og:description"\n        content="Fastest way to Manage your Job Search from your Mobile Anytime, Anywhere. Get Yourself Registered, Download the App and Get Referred in Top Companies in India" />\n    <meta http-equiv="content-language" content="en-us" />\n    <link href="https://fonts.googleapis.com/css?family=PT+Sans:400,700&display=swap" rel="stylesheet">\n    <script>\n        /*! loadCSS. [c]2017 Filament Group, Inc. MIT License */\n        !function (a) { "use strict"; var b = function (b, c, d) { function j(a) { if (e.body) return a(); setTimeout(function () { j(a) }) } function l() { f.addEventListener && f.removeEventListener("load", l), f.media = d || "all" } var g, e = a.document, f = e.createElement("link"); if (c) g = c; else { var h = (e.body || e.getElementsByTagName("head")[0]).childNodes; g = h[h.length - 1] } var i = e.styleSheets; f.rel = "stylesheet", f.href = b, f.media = "only x", j(function () { g.parentNode.insertBefore(f, c ? g : g.nextSibling) }); var k = function (a) { for (var b = f.href, c = i.length; c--;)if (i[c].href === b) return a(); setTimeout(function () { k(a) }) }; return f.addEventListener && f.addEventListener("load", l), f.onloadcssdefined = k, k(l), f }; "undefined" != typeof exports ? exports.loadCSS = b : a.loadCSS = b }("undefined" != typeof global ? global : this);\n        /*! loadCSS rel=preload polyfill. [c]2017 Filament Group, Inc. MIT License */\n        !function (a) { if (a.loadCSS) { var b = loadCSS.relpreload = {}; if (b.support = function () { try { return a.document.createElement("link").relList.supports("preload") } catch (a) { return !1 } }, b.poly = function () { for (var b = a.document.getElementsByTagName("link"), c = 0; c < b.length; c++) { var d = b[c]; "preload" === d.rel && "style" === d.getAttribute("as") && (a.loadCSS(d.href, d, d.getAttribute("media")), d.rel = null) } }, !b.support()) { b.poly(); var c = a.setInterval(b.poly, 300); a.addEventListener && a.addEventListener("load", function () { b.poly(), a.clearInterval(c) }), a.attachEvent && a.attachEvent("onload", function () { a.clearInterval(c) }) } } }(this);\n    </script>\n    <link rel="stylesheet" href="https://static1.shine.com/c/s1/CACHE/css/5b35a84869a4.css" type="text/css" />\n\n    \n<script>/*<![CDATA[*/\n   var\n       sc = {};sc.showBlocker = \'\';sc.url_prefix = \'https://www.shine.com/\';sc. ...

# %%
import requests
from bs4 import BeautifulSoup
  
URL = "https://www.shine.com/"
r = requests.get(URL)
  
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Jobs 2022 - Search Jobs in India, Latest Job Vacancies, Recruitment - Shine.com
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="en-us" http-equiv="content-language"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="87369453667" property="fb:app_id"/>
#   <meta content="Shine" property="og:site_name"/>
#   <meta content="company" property="og:type"/>
#   <meta content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" property="og:image"/>
#   <meta content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" itemprop="image"/>
#   <link href="https://static1.shine.com/c/s1/images/favicon.ico" rel="SHORTCUT ICON"/>
#   <link href="https://www.shine.com/search.xml" rel="search" title="jobs on Shine.com" type="application/opensearchdescription+xml"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Shine.com is India's Leading Online Job and Recruitment Portal - Search &amp; Apply for Latest Job Vacancies across Top Companies in India. Register FREE Now!" name="description"/>
#   <meta content="Shine.com : One Stop Destination To Find Your Dream Job on the Go" property="og:title"/>
#   <meta content="job, jobs, job in india, job search, job vacancies, job openings, find jobs, shine, jobs for freshers, apply jobs" name="keywords"/>
#   <meta content="https://www.shine.com/" property="og:url"/>
#   <meta content="Fastest way to Manage your Job Search from your Mobile Anytime, Anywhere. Get Yourself Registered, Download the App and Get Referred in Top Companies in India" property="og:description"/>
#   <meta content="en-us" http-equiv="content-language"/>
#   <link href="https://fonts.googleapis.com/css?family=PT+Sans:400,700&amp;display=swap" rel="stylesheet"/>
#   <script>
#    /*! loadCSS. [c]2017 Filament Group, Inc. MIT License */
#         !function (a) { "use strict"; var b = function (b, c, d) { function j(a) { if (e.body) return a(); setTimeout(function () { j(a) }) } function l() { f.addEventListener && f.removeEventListener("load", l), f.media = d || "all" } var g, e = a.document, f = e.createElement("link"); if (c) g = c; else { var h = (e.body || e.getElementsByTagName("head")[0]).childNodes; g = h[h.length - 1] } var i = e.styleSheets; f.rel = "stylesheet", f.href = b, f.media = "only x", j(function () { g.parentNode.insertBefore(f, c ? g : g.nextSibling) }); var k = function (a) { for (var b = f.href, c = i.length; c--;)if (i[c].href === b) return a(); setTimeout(function () { k(a) }) }; return f.addEventListener && f.addEventListener("load", l), f.onloadcssdefined = k, k(l), f }; "undefined" != typeof exports ? exports.loadCSS = b : a.loadCSS = b }("undefined" != typeof global ? global : this);
#         /*! loadCSS rel=preload polyfill. [c]2017 Filament Group, Inc. MIT License */
#         !function (a) { if (a.loadCSS) { var b = loadCSS.relpreload = {}; if (b.support = function () { try { return a.document.createElement("link").relList.supports("preload") } catch (a) { return !1 } }, b.poly = function () { for (var b = a.document.getElementsByTagName("link"), c = 0; c < b.length; c++) { var d = b[c]; "preload" === d.rel && "style" === d.getAttribute("as") && (a.loadCSS(d.href, d, d.getAttribute("media")), d.rel = null) } }, !b.support()) { b.poly(); var c = a.setInterval(b.poly, 300); a.addEventListener && a.addEventListener("load", function () { b.poly(), a.clearInterval(c) }), a.attachEvent && a.attachEvent("onload", function () { a.clearInterval(c) }) } } }(this);
#   </script>
#   <link href="https://static1.shine.com/c/s1/CACHE/css/5b35a84869a4.css" rel="stylesheet" type="text/css"/>
#   <script>
#    /*<![CDATA[*/
#    var
#        sc = {};sc.showBlocker = '';sc.url_prefix = 'https://www.shine.com/';sc.url_prefix_media = "https://static1.shine.com/c/s1/";sc.url_prefix_images = "https://static1.shine.com/c/s1/"+'images/';sc.url_prefix_lookups = 'https://www.shine.com/'+'lookup/';sc.IsMidOut = '';sc.IsResumeMidOut = '';sc.next = '';sc.BounceStatus=0;sc.UID = 0;sc.LOGGEDIN = false;sc.MobileNo=0;sc.CountryCode='';sc.NAME = undefined;sc.FIRST_NAME = undefined;sc.LAST_NAME = undefined;sc.on_live = 1;sc.portal = 'recruiter';sc.CSRF_TOKEN='<input type="hidden" name="csrfmiddlewaretoken" value="DyDK827WpuuUWXxdqJek0t4ljQF3ivUU7yYw3jF4Af7wSeIIq0r4CEx2bdxOptrE">';sc.oldResume=0;sc.oldMobile=0;sc.itSkills=0;sc.androidApp=0;sc.incorrectFA=0;sc.incorrectMobile=0;sc.linkedin_apply_url='https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Fapply';sc.linkedin_login_url='https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Flogin';sc.url_prefix_withOutSlash=sc.url_prefix.slice(0,-1);sc.jobSeekerFlag='';sc.badProfile='';sc.clientData={};sc.clientData["currentSalaryL"]='';sc.clientData["currentSalT"]='';sc.clientData["currentExpY"]='';sc.clientData["currentExpM"]='';sc.truecaller_app_key='op5HY04fda58730dc418c8fb43a78543b7cba';sc.is_fresher=''; sc.learning_domain='https://learning.shine.com'; sc.learning_products_info={'application_highlighter': {'product_id': 4117, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4117&lc=1'}, 'shine_premium_1_month': {'product_id': 4573, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4573&lc=1'}, 'shine_premium_2_month': {'product_id': 4574, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4574&lc=1'}, 'profile_booster': {'product_id': 4561, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4561&lc=1'}, 'expert_help_0_to_1_year': {'product_id': 1921, 'url': 'https://resume.shine.com/product/freshers-level/1921?lc=1'}, 'expert_help_1_to_4_year': {'product_id': 1922, 'url': 'https://resume.shine.com/product/entry-level/1922?lc=1'}, 'expert_help_4_to_8_year': {'product_id': 1923, 'url': 'https://resume.shine.com/product/mid-level/1923?lc=1'}, 'expert_help_8_to_15_year': {'product_id': 1924, 'url': 'https://resume.shine.com/product/senior-level/1924?lc=1'}, 'expert_help_15_plus_year': {'product_id': 32, 'url': 'https://resume.shine.com/product/executive-level/32?lc=1'}, 'jobs_on_the_move': {'product_id': 3414, 'url': 'https://resume.shine.com/product/jobs-on-the-move-4/3414?lc=1'}, 'interview_preparation': {'product_id': 38, 'url': 'https://learning.shine.com/courses/personal-development/interview-preparation/38/?lc=1'}, 'resume_builder_1_year': {'product_id': 4527, 'url': 'https://resume.shine.com/product/resume-builder-1-year-rs-499/4527?lc=1'}, 'resume_builder_14_days': {'product_id': 4526, 'url': 'https://resume.shine.com/product/resume-builder-14-days-rs-199/4526?lc=1'}, 'featured_profile': {'product_id': 1939, 'url': 'https://resume.shine.com/product/featured-profile-10/1939?lc=1'}, 'linkedin_profile_0_to_1_year': {'product_id': 1926, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/entry-level-2/1926/?lc=1'}, 'linkedin_profile_1_to_4_year': {'product_id': 1925, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/fresher-level/1925/?lc=1'}, 'linkedin_profile_4_to_8_year': {'product_id': 1927, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/mid-level-2/1927/?lc=1'}, 'linkedin_profile_8_to_15_year': {'product_id': 1928, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/senior-level-2/1928/?lc=1'}, 'linkedin_profile_15_plus_year': {'product_id': 3 ...
#
# /*]]>*/
#   </script>
#   <script src="https://static1.shine.com/c/s1/CACHE/js/fcefed5c177c.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://static1.shine.com/c/s1/CACHE/js/ed5d7919f173.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function(p, l, o, w, i, n, g) {
#             if (!p[i]) {
#                 p.GlobalTrackerNamespace = p.GlobalTrackerNamespace || [];
#                 p.GlobalTrackerNamespace.push(i);
#                 p[i] = function() {
#                     (p[i].q = p[i].q || []).push(arguments);
#                 };
#                 p[i].q = p[i].q || [];
#                 n = l.createElement(o);
#                 g = l.getElementsByTagName(o)[0];
#                 n.async = 1;
#                 n.src = w;
#                 g.parentNode.insertBefore(n, g);
#                 p['platform'] = "web";
#             }
#         }
#         (window, document, "script", "https://analytics.htmedia.in/analytics-js/shinedap.js", "dapCollector"));
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3537905-1">
#   </script>
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function () {
#             googletag.defineSlot('/1055314/sh_homepage_lhs_300x250', [300, 250], 'div-gpt-ad-1404815449201-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#             googletag.defineSlot('/1055314/Shine_HTNewsWidget_300x250', [300, 250], 'div-gpt-ad-1404818223391-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#             googletag.pubads().set("page_url", "https://www.shine.com/");//14425760768570183945
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().disableInitialLoad();
#             googletag.enableServices();
#         });
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({
#                 'gtm.start':
#                     new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-TFD6PTW');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- ads handling script -->
#   <script data-cfasync="false" type="text/javascript">
#    (function(w, d) {
#         var s = d.createElement('script');
#         s.src = '//cdn.adpushup.com/42718/adpushup.js';
#         s.crossOrigin='anonymous';
#         s.type = 'text/javascript'; s.async = true;
#         (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s);
#         })(window, document);
#   </script>
#   <!-- End ads handling script -->
#   <script async="" data-ad-client="ca-pub-9783515403541006" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script type="application/ld+json">
#    {
#      "@context" : "http://schema.org",
#      "@type" : "Organization",
#      "name" : "Shine",
#      "url" : "https://www.shine.com",
#      "sameAs" : ["https://www.facebook.com/shinedotcom/", "https://twitter.com/Shinedotcom?lang=en", "https://plus.google.com/+shinecom", "https://www.youtube.com/user/ShineJobs", "https://www.linkedin.com/company/shinecom/" ]
#    }
#   </script>
#   <script type="text/javascript">
#    sc.LOGGEDIN = false;
#
#         //works when user is not logged in
#         function keepmeloggedin() {
#             try {
#                 var e = {};
#                 common.cookiename = "_kmsi_";
#                 e.c = common.readCookie();
#
#                 if (e.c != null && e.c != "") {
#                     e.d = e.c.replace(/"/g, "");
#                     if (e.d != void 0 && e.d != undefined && e.d != "undefined" && e.d.length > 1) {
#                         top.window.location = sc.url_prefix + "myshine/login/" + e.d + "/"
#                     }
#                 }
#             } catch (t) {
#             }
#         }
#         function redirectmyshinehome() {
#             common.cookiename = "_em_";
#             var e = {};
#             e.c = common.readCookie();
#             if (e.c != null && e.c != "" && e.c != "-1") {
#                 common.homepage = true;
#                 common.makeajax()
#             }
#         }
#         redirectmyshinehome();
#         keepmeloggedin();
#   </script>
#   <meta content="jzyKWIQOhsVNrHIxFkAVABnuY3HLZ4YNrV55n6Pt538" name="google-site-verification"/>
#  </head>
#  <body>
#   <div id="opaque">
#   </div>
#   <div class="container-fluid">
#    <div class="row">
#     <header class="pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2 fixed-top">
#      <nav class="navbar navbar-expand-sm navbar-dark navbar-inverse">
#       <!-- Brand -->
#       <a class="navbar-brand" href="#">
#       </a>
#       <!-- Links -->
#       <ul class="navbar-nav">
#        <li class="nav-item dropdown pr-2 pl-2">
#         <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs', 'Jobs in Top Cities, Jobs by Skills, Jobs by Courses, Jobs by Education, Jobs by Designation, Jobs by Company')">
#          Search Jobs
#         </a>
#         <div class="dropdown-menu sm-menu">
#          <a class="dropdown-item" href="/jobs-in-top-cities" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs in Top Cities')">
#           Jobs in Top Cities
#          </a>
#          <a class="dropdown-item" href="/jobs-by-skills" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Skills')">
#           Jobs by Skills
#          </a>
#          <a class="dropdown-item" href="/jobs-by-courses" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Courses')">
#           Jobs by Courses
#          </a>
#          <a class="dropdown-item" href="/jobs-by-education" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Education')">
#           Jobs by Education
#          </a>
#          <a class="dropdown-item" href="/jobs-by-designation" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Designation')">
#           Jobs by Designation
#          </a>
#          <!-- <a class="dropdown-item" href="/government-job-openings">Government Jobs</a>
#                         <a class="dropdown-item" href="/part-time-jobs">Part Time Jobs</a> -->
#          <a class="dropdown-item" href="/jobs-by-top-company" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Companies')">
#           Jobs by Companies
#          </a>
#         </div>
#        </li>
#        <li class="nav-item">
#        </li>
#        <li class="nav-item dropdown pr-2 pl-2">
#         <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="window.open('https://learning.shine.com/?utm_source=shine&amp;utm_medium=header'); MyGA.SendEvent('homepage_navigation','homepage_navigation','services', 'Digital Marketing, Data Science, Cloud Computing, GST, Prject Management, Six Sigma, Resume Writing, International Resume, LinkedIn Profile Writing, Jobs on the Move, Resume Formats, Resignation Letter Format')">
#          Services
#         </a>
#         <div class="dropdown-menu service_dropdown">
#          <div class="learning">
#           <strong>
#            E-learning
#           </strong>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/sales-and-marketing/digital-marketing/32/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Digital Marketing')">
#            Digital Marketing
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/it-information-technology/data-science/497/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Data Science')">
#            Data Science
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/it-information-technology/cloud-computing/82/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Cloud Computing')">
#            Cloud Computing
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/banking-finance/gst-2/507/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','GST')">
#            GST
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/operation-management/project-management/123/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Project Management')">
#            Project Management
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/operation-management/six-sigma/193/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Six Sigma')">
#            Six Sigma
#           </a>
#          </div>
#          <div class="learning">
#           <strong>
#            Resume Service
#           </strong>
#           <a class="dropdown-item" href="https://resume.shine.com/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resume Writing')">
#            Resume Writing
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/product/entry-level-freshers-4/2553?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','International Resume')">
#            International Resume
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/product/linkedin-profile-writing/entry-level-2/1926?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','LinkedIn Profile Writing')">
#            LinkedIn Profile Writing
#           </a>
#           <a class="dropdown-item" href="	https://resume.shine.com/product/jobs-on-the-move-4/3414?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Jobs on the Move')">
#            Jobs on the Move
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/cms/resume-format/1?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resume Formats')">
#            Resume Formats
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/cms/resignation-letter-formats-samples/3/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resignation Letter Format')">
#            Resignation Letter Format
#           </a>
#          </div>
#         </div>
#        </li>
#        <!-- Dropdown -->
#        <li class="nav-item dropdown pr-2 pl-2">
#         <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources', 'Blog, Resume Tips, Career Help, Career Prospects, Job Search Guidance, Interview Tips')">
#          Resources
#         </a>
#         <div class="dropdown-menu">
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Blog')" target="_blank">
#           Blog
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/resume-tips/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Resume Tips')" target="_blank">
#           Resume Tips
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/career-help/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Career Help')" target="_blank">
#           Career Help
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/career-prospects/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Career Prospects')" target="_blank">
#           Career Prospects
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/job-search-guidance/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Job Search Guidance')" target="_blank">
#           Job Search Guidance
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/interview-tips/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Interview Tips')" target="_blank">
#           Interview Tips
#          </a>
#         </div>
#        </li>
#        <li class="nav-item pr-2 pl-2 br-round">
#         <a class="nav-link" href="https://recruiter.shine.com/?utm_source=shine&amp;utm_medium=header&amp;utm_campaign=CandidateHeader" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_recruiter')" title="Recruiter Zone">
#          Recruiter
#         </a>
#        </li>
#        <li class="nav-item pr-2 pl-2 br-round">
#         <a class="nav-link" href="/job-search/walkin-jobs" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_walkins')" title="Walk-ins">
#          Walk-ins
#         </a>
#        </li>
#        <li class="nav-item pr-2 pl-2 br-round covid">
#         <a class="nav-link" href="https://learning.shine.com/user-intent" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_covid-19_career_guide')" target="_blank">
#          Career Guidance
#          <sup>
#           NEW
#          </sup>
#         </a>
#        </li>
#       </ul>
#       <ul class="navbar-nav ml-auto">
#        <li class="nav-item">
#         <a class="nav-link outerborder pr-3 pl-3 mr-4" href="/free-job-alerts/" onclick="MyGA.SendEvent('homepage_jobalert_postajob','homepage_jobalert_postajob','click_jobalert','create job alert')">
#          Create job alert
#         </a>
#        </li>
#        <li class="nav-item">
#         <a class="nav-link outerborder pr-3 pl-3" href="https://recruiter.shine.com/online-package/offer/free-job-posting/?utm_source=shine&amp;utm_medium=header&amp;utm_campaign=CandidateHeader" onclick="MyGA.SendEvent('homepage_jobalert_postajob','homepage_jobalert_postajob','click_postajob','post a job')" title="Post a job">
#          Post a job
#         </a>
#        </li>
#        <li class="nav-item number pl-2">
#         080-47105555
#         <small>
#          9am - 6pm, Mon to Sat
#         </small>
#        </li>
#       </ul>
#      </nav>
#     </header>
#     <section class="home_mid container-fluid pt-4 cls_withoutform cls_form">
#      <div class="d-flex pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2 justify-content-between">
#       <div class="flex-row mt-1 pl-4 col-6">
#        <h1>
#         Growth on your mind?
#        </h1>
#        <h2>
#         Explore 300,000+ jobs
#        </h2>
#        <div class="inputstyle d-flex mt-4 p-4 align-items-center" id="id_showform">
#         Job title, skills
#        </div>
#       </div>
#       <div class="registration flex-row fl mt-2 p-5">
#        <a href="/registration/parser/" onclick="MyGA.SendEvent('homepage_login_register', 'homepage_login_register', 'click_register', 'register for free')">
#         <button class="btn btn-primary btn-yellow" type="button">
#          Register for free
#         </button>
#        </a>
#        <div class="sign_in pl-5 pt-4 ml-3">
#         <a class="cls_register_signin_homepage cls_login_header cls_call_dialogbox" data-category="signin" data-from="header" data-popuptype="4" href="/myshine/login/" onclick="MyGA.SendEvent('homepage_login_register', 'homepage_login_register', 'click_signin', 'sign in')" title="Jobseeker Login">
#          Sign in
#         </a>
#        </div>
#       </div>
#      </div>
#     </section>
#     <div class="home_mid_open pt-4 cls_form cls_withform hide">
#      <div class="d-flex pl-5 pr-5 justify-content-between">
#       <div class="flex-column mt-1 pl-4 col-12">
#        <h1 class="mb-3">
#         Growth on your mind?
#         <span class="close_form" id="id_hideform">
#         </span>
#        </h1>
#        <div class="hsearch d-flex flex-column flex-wrap">
#         <div class="advancsearch">
#          <form action="//www.shine.com/job-search/" class="cls_frm_reg_job_srch cls_txtanimation animation" data-errorcode="err_1" id="frm_adv_srch" method="post" novalidate="" onsubmit="common.stopBeforeJavascriptLoad(); searchAnalytics('frm_adv_srch', 'searchForm')">
#           <div class="cls_sel_serch_jobs cls_search_jobs search_left">
#            <ul>
#             <li class="key Kjob">
#              <label class="lbl">
#               Job title, skills
#              </label>
#              <input aria-label="Job title,skills" class="cls_input_validate cls_local_autocomplete search3" data-rulesid="01" data-selecttype="multiple" id="id_q" maxlength="150" name="q" required="" tabindex="0" type="text"/>
#             </li>
#             <li class="key homepageloc">
#              <label class="lbl">
#               Location
#              </label>
#              <input aria-label="Location" class="search3" id="id_loc" maxlength="150" name="loc" tabindex="0" type="text"/>
#             </li>
#             <li class="key key1 kexp">
#              <label class="lbl">
#               Experience
#              </label>
#              <select aria-label="Experience" class="styled cls_minval" id="id_minexp" name="minexp">
#               <option selected="" value="">
#                Experience (Years)
#               </option>
#              </select>
#             </li>
#            </ul>
#            <div class="clear">
#            </div>
#            <ul class="floatleft cls_ulAdvSearch" id="adv_srch" style="display: none;">
#             <li class="key key1 kexp1">
#              <label class="lbl">
#               Salary
#              </label>
#              <select aria-label="Salary" class="styled cls_minval" id="id_minsal" name="minsal">
#               <option selected="" value="">
#                Salary (Lakh/Year)
#               </option>
#              </select>
#             </li>
#             <li class="key key1 kexp1">
#              <label class="lbl">
#               Department
#              </label>
#              <select aria-label="Department" class="cls_input_validate styled" data-rulesid="01" id="id_area" name="area">
#               <option selected="" value="">
#                Department
#               </option>
#              </select>
#             </li>
#             <li class="key key1 kexp1" style="margin-right:none;">
#              <label class="lbl">
#               Industry
#              </label>
#              <select aria-label="Industry" class="cls_input_validate styled" data-rulesid="01" id="id_ind" name="ind">
#               <option selected="" value="">
#                Industry
#               </option>
#              </select>
#             </li>
#            </ul>
#            <li class="but1">
#             <input id="id_head_trigger_advSrch" name="advSrch" type="hidden" value="false"/>
#            </li>
#           </div>
#           <div class="expand" name="adv_srch">
#            <input aria-label="id_search_form" class="cls_btn_reg_job_srch cls_searchbtnabv submit" id="id_search_form" name="simplesearch" type="submit" value="Submit"/>
#            <a class="cls_ulAdvSearch_a" data-searchtype="adv_srch" href="javascript:void(0);">
#             <u>
#              Advanced search
#             </u>
#            </a>
#           </div>
#           <input id="formmd5" name="formmd5" type="hidden" value=""/>
#           <input id="id_best_matches" name="best_matches" type="hidden" value=""/>
#           <input id="id_posted_after" name="posted_after" type="hidden" value=""/>
#          </form>
#         </div>
#         <!--
# <input type="submit" value="" class="redbtn cls_btn_reg_job_srch_lrg" name="Submit" />
# -->
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--cool places to work start-->
#     <div class="flex-column mt-2 col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#      <h2 class="text-center">
#       Cool places to work
#      </h2>
#      <ul class="cool d-flex flex-row mt-3 justify-content-around">
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=497070&amp;next=https://recruiter.shine.com/micro-site/aditya-birla-group-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Aditya Birla Management Corporation Pvt. Ltd.')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/608a7830f65e4ac4a70869e145c55c25.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/449660b6ea5c4aada2e211f4831cc945.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=654568&amp;next=https://www.shine.com/job-search/teleperformance-global-services-pvt-ltd-openings?rect=654568" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Teleperformance Global Services Pvt Ltd,')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/d98a014b326648178fbb08eef46ac70e.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6c23dfb3c9224480870c900b8dddf299.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=677780&amp;next=https://www.shine.com/job-search/sbi-life-insurance-company-limited-openings?rect=677780" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','SBI Life Insurance Company Limited')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/7a22c70f27904e2e81d7ebd1066d55e1.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/17e4d7d8d2bf419eb023429afacb5154.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=532598&amp;next=https://recruiter.shine.com/micro-site/infosys-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Infosys Limited')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/26c83ce6d9df4733a9bbc06d2e3b8f0e.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/19b43e6c9ee345faa75540f998db7441.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=55437&amp;next=https://recruiter.shine.com/micro-site/genpact-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Genpact India Pvt Ltd')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/c250bee50f5b490aac4b63fe281ab79e.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/4ba34994bc414de7984c38c9cee86ebe.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#      </ul>
#     </div>
#     <!--cool places to work ends-->
#     <!--Top companies hiring starts-->
#     <div class="flex-column mt-4 mb-4 col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#      <h2 class="text-center pt-3">
#       Top companies hiring now
#      </h2>
#      <ul class="top_employer d-flex flex-row mb-5 mt-3 flex-wrap">
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=700272&amp;next=https://www.shine.com/job-search/reliance-nippon-life-insurance-company-limited-openings?rect=700272" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','RELIANCE NIPPON LIFE INSURANCE COMPANY LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/ab28f0af876f42cb96302faaea9e1671.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=699516&amp;next=https://recruiter.shine.com/micro-site/hewlett-packard-enterprise-jobs/" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Futurestep Recruitment Services Private Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/8ec12c71c03445248ec99942e16a812c.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=604202&amp;next=https://www.shine.com/job-search/yes-bank-ltd-openings?rect=604202" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Yes Bank Ltd')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/8b3d3868f9444657ad239ed43eb423b8.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=763688&amp;next=https://www.shine.com/job-search/tata-consultancy-services-limited-openings?rect=763688" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Tata Consultancy Services Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/b076fc83cebb42069205c9a410c9f618.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=735396&amp;next=https://www.shine.com/job-search/icici-bank-ltd-openings?rect=735396" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','ICICI Bank Ltd')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/9f53b7d4345d41ac9b657b726b6b3349.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=648608&amp;next=https://www.shine.com/job-search/aegis-customer-support-services-private-limited-openings?rect=648608" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Aegis Customer Support Services Private Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/da1f7501c8f740498dbb4b28fde081c2.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=700277&amp;next=https://www.shine.com/job-search/reliance-general-insurance-company-limited-openings?rect=700277" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','RELIANCE GENERAL INSURANCE COMPANY LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/f85756b6a88e4997beaf87c6f1bb5cfd.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=641256&amp;next=https://www.shine.com/job-search/cms-it-services-private-limited-openings?rect=641256" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','CMS IT SERVICES PRIVATE LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/f548e2c309c24db1a8b9d4ff9d97b02e.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=670803&amp;next=https://www.shine.com/job-search/tech-mahindra-ltd-openings?rect=670803" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Tech Mahindra Ltd.')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/a307d745fbbe46d3822e5b4e6f3fed55.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=683181&amp;next=https://www.shine.com/job-search/max-life-insurance-co-ltd-openings?rect=683181" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Max life insurance Co. LTD.')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6cf7d2611de84b7585d75db2f40e81b8.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=751515&amp;next=https://www.shine.com/job-search/d-mart-openings?rect=751515" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Avenue Supermarts Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/24d6c76bfae84a6f8bd18522f4744b3a.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=754750&amp;next=https://www.shine.com/job-search/byjus-openings?rect=754750" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','THINK &amp; LEARN PRIVATE LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/9b944622fc46422786322e57d29a4225.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=709489&amp;next=https://www.shine.com/job-search/steria-jobs" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Steria (India) Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/666b83a3c4974b4f92613fce536a4251.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=677780&amp;next=https://www.shine.com/job-search/sbi-life-insurance-company-limited-openings?rect=677780" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','SBI Life Insurance Company Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/7f5bc2c5010f4e0fbff014205842ff27.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=736552&amp;next=https://recruiter.shine.com/micro-site/indegene-private-limited-jobs/" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Indegene Private Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/700cc0d27c8b416bbfb9c2765652c9cd.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=739959&amp;next=https://www.shine.com/job-search/anand-rathi-share-and-stock-brokers-limited-openings?rect=739959" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','ANAND RATHI SHARE AND STOCK BROKERS LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/32ff5f1937b14c1d96212a1cfb563860.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=385010&amp;next=https://www.shine.com/job-search/quotes-kotak-mahindra-bank-limited-quotes-jobs?fcid=385010" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Kotak Mahindra Bank Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/264470edd81541d190bc774a279534aa.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=101888&amp;next=https://www.shine.com/job-search/k12-techno-services-pvt-ltd-openings?rect=101888" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','K12 Techno Services Pvt. Ltd')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6f1e554cc7fd4ab89210fb651db329ea.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=745952&amp;next=https://www.shine.com/job-search/dbs-bank-india-limited-openings?rect=745952" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','DBS BANK INDIA LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/956bad7a7ab24728bff6ca4383565b29.png"/>
#        </a>
#       </li>
#      </ul>
#      <div class="white_button col-2">
#       <a href="/company-branding" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','view_all_top_companies')" target="_blank">
#        View all top companies
#       </a>
#      </div>
#     </div>
#     <!--Top companies hiring Ends-->
#     <!--Banner ad starts-->
#     <div class="container-fluid">
#      <div class="banner_container">
#       <div class="row">
#        <div class="d-flex mt-4 w-100 col-12 banner_mid_home">
#         <div>
#          <a href="https://amazonvirtualhiring.hirepro.in/registration/incta/ju0f4/apply/?j=56357&amp;e=12210" id="id_banglore-banner" style="display: none;">
#           <img class="lozad small_ad" data-src="https://static1.shine.com/c/s1/images/candidate/new/Amazon-Ad-Transaction-Risk-Investigator---SPRO-Hyderabad.gif" height="250" width="300"/>
#          </a>
#          <a href="https://amazonvirtualhiring.hirepro.in/registration/incta/ju0f4/apply/?j=56416&amp;e=12247" id="id_hyderabad-banner" style="display: none;">
#           <img class="lozad small_ad" data-src="https://static1.shine.com/c/s1/images/candidate/new/Amazon-Ad-Transaction-Risk-Investigator---SPRO-Bangalore.gif" height="250" width="300"/>
#          </a>
#         </div>
#         <div>
#          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=532598&amp;next=https://recruiter.shine.com/micro-site/infosys-jobs/restart-with-infosys/417/&amp;_ga=2.58698409.2024220180.1578306174-1942937461.1578306173" onclick="MyGA.SendEvent('homepage_ad', 'homepage_ad', 'click_recruiterad')" target="_blank">
#           <img class="lozad" data-src="https://static1.shine.com/c/s1/images/candidate/new/ad_banner_new1.png" height="250" width="779"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--Banner ad Ends -->
#    </div>
#   </div>
#   <!--why shine starts-->
#   <div class="container-fluid mt-4">
#    <div class="row">
#     <div class="col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#      <div class="whyshine m-5">
#       <h2 class="text-center pt-5 pb4">
#        Why Shine
#       </h2>
#       <div class="d-flex justify-content-between pt-4">
#        <div class="flex-row candidates">
#         <p class="d-flex flex-column mt-2">
#          <strong class="d-flex flex-column">
#           3.4
#                                     crores+
#          </strong>
#          <span class="d-flex flex-column">
#           Candidates
#          </span>
#         </p>
#        </div>
#        <div class="flex-row jobs">
#         <p class="d-flex flex-column mt-2">
#          <strong class="d-flex flex-column">
#           300,000+
#          </strong>
#          <span class="d-flex flex-column">
#           Jobs
#          </span>
#         </p>
#        </div>
#        <div class="flex-row companies">
#         <p class="d-flex flex-column mt-3">
#          <strong class="d-flex flex-column">
#           15,000+
#          </strong>
#          <span class="d-flex flex-column">
#           Companies
#          </span>
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--why shine Ends -->
#   <div class="container-fluid premium_base">
#    <div class="graph_image_premium">
#    </div>
#    <a data-cartaddition="True" data-position="4" data-products="4" data-source="static" data-subproducts="None" data-tid="620a43c805e3fbf82d74fb7d" data-tracking='{"trigger_point": 13, "u_id": null}' id="id_shine_premium" onclick="redirectShinePremiumPage('620a43c805e3fbf82d74fb7d','{&quot;trigger_point&quot;: 13, &quot;u_id&quot;: null}','4', 'static');MyGA.SendEvent('homepage_premium', 'homepage_premium', 'click_getshinepremium')">
#     <div class="fasttrack-banner">
#      <span class="premium_crown">
#      </span>
#      <div class="fasttrack-banner_text">
#       <span class="shinepremium_head">
#        Shine Premium
#       </span>
#      </div>
#      <div class="shinepremium_content">
#       <span>
#        <strong>
#         Fastrack your job
#        </strong>
#        search with our premium services
#       </span>
#       <ul class="fastrack_banner_web">
#        <li>
#         Enhanced Profile
#        </li>
#        <li>
#         10x higher visibility to recruiters
#        </li>
#        <li>
#         Insights on other applicants
#        </li>
#        <li>
#         Interview Ready
#        </li>
#       </ul>
#       <div class="get-start-btn">
#        Get Shine Premium
#       </div>
#      </div>
#     </div>
#    </a>
#    <script>
#     window.touchpointTrackingMap && (touchpointTrackingMap.id_shine_premium = function() {
#         /*
# ...
#          Apply with Linkedin
#         </div>
#        </a>
#       </li>
#       <li class="msite_displaynone socialLogin">
#        <div class="social-login--btn google_button customBtn" data-actiontype="login" data-formtobesubmitted="id_applyWithGoogle" id="gSignInWrapper" onclick="MyGA.SendEvent('LoginPopup','Google')">
#         <div class="social-login--icon">
#          <i class="icon google">
#          </i>
#         </div>
#         <div class="social-login--text google msite_displaynone">
#          Apply with Google
#         </div>
#        </div>
#       </li>
#       <li class="msite_displaynone">
#        <div class="social-login--btn facebook_button" data-actiontype="login" data-formtobesubmitted="id_applyWithFB" id="id_loginWithFB" onclick="MyGA.SendEvent('LoginPopup','facebook')">
#         <div class="social-login--icon">
#          <i class="icon facebook">
#          </i>
#         </div>
#         <div class="social-login--text msite_displaynone">
#          Apply with Facebook
#         </div>
#        </div>
#       </li>
#      </ul>
#      <!----
#         Login with
#       -->
#      <ul class="cls_base_1 lgn_right lgn_right_linkedin social-login cls_social_login">
#       <li class="msite_displaynone socialLogin">
#        <div class="social-login--btn google_button customBtn" data-actiontype="login" data-formtobesubmitted="id_loginWithGoogle" id="gSignInWrapper" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','google')">
#         <div class="social-login--icon">
#          <i class="icon google">
#          </i>
#         </div>
#         <div class="social-login--text google msite_displaynone">
#          Sign-in with Google
#         </div>
#        </div>
#       </li>
#       <li class="recentsearches msite_displaynone socialLogin">
#        <a class="social-login--btn linkedin_button" href="https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Flogin" id="id_loginWithLinkedinUrl" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','Linkedin');">
#         <div class="social-login--icon">
#          <i class="icon linkedin">
#          </i>
#         </div>
#         <div class="social-login--text msite_displaynone">
#          Sign-in with Linkedin
#         </div>
#        </a>
#       </li>
#       <li class="msite_displaynone">
#        <div class="social-login--btn facebook_button" data-actiontype="login" data-formtobesubmitted="id_loginWithFbForm" id="id_loginWithFB" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','facebook')">
#         <div class="social-login--icon">
#          <i class="icon facebook">
#          </i>
#         </div>
#         <div class="social-login--text msite_displaynone">
#          Sign-in with Facebook
#         </div>
#        </div>
#       </li>
#       <!-- <li class="d-block text-center mt-4 regbtnText" style="width: 100%;">
#           Don't have Shine account?
#           <a href="/registration/parser/" class="white_button d-block col-7 mt-2 regBtn apply m-auto-temp"
#             onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','register now')"
#           >Register
#             now</a>
#         </li> -->
#      </ul>
#      <div class="cls_registernow register_bottom cls_base_1">
#       Don't have Shine account?
#       <a href="/registration/parser/" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','register now')">
#        Register
#             now
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="forget_password modal standard_form_class" id="id_candidateforgotpassword" style="display: none;">
#    <div class="overlay">
#    </div>
#    <div class="modal_content">
#     <div class="modal_titlebar">
#      <span id="ui-id-1">
#       Forget Password
#      </span>
#      <a class="close" id="id_fpCancel">
#       <span class="">
#       </span>
#      </a>
#     </div>
#     <div class="" id="id_candidateforgotpassword">
#      <div class="forget m-4" id="id_fPForm">
#       <span>
#        Enter the Email ID with which you are registered on Shine.com
#       </span>
#       <form action="javascript:void(0);" id="id_forgotPassword" method="POST" novalidate="novalidate" onsubmit="return false">
#        <ul>
#         <li>
#          <input aria-label="Email Id" id="candidateemailid" name="email" placeholder="Email" type="text"/>
#         </li>
#        </ul>
#       </form>
#      </div>
#      <div id="id_successMsg_fp" style="display: none; padding-left: 5%">
#       A link to reset your Shine Password has been sent to your Email Id
#      </div>
#     </div>
#     <div class="popup_button_pannel">
#      <button class="highlight_button" id="id_fpSubmit" type="button">
#       Submit
#      </button>
#      <button class="highlight_button" id="id_fpCancelButton" style="display: none;" type="button">
#       Ok
#      </button>
#     </div>
#    </div>
#   </div>
#   <script src="https://apis.google.com/js/api:client.js">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js">
#   </script>
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <script src="https://static1.shine.com/c/s1/CACHE/js/9c4922e93e01.js" type="text/javascript">
#   </script>
#   <script src="https://static1.shine.com/c/s1/CACHE/js/ab53d675170b.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://static1.shine.com/c/s1/CACHE/js/98179a304fa6.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function () {
#             /* Page View Analytics Non Logged In */
#             // window.dapCollector('trackPageView', document.title);
#             let liveMintValue = "True";
#             if(liveMintValue == "True"){
#                 setTimeout(function(){window.dapCollector("trackImpression", "~", "vertical", 1, "Shine Homepage", "Livemint Homepage", "https://www.livemint.com/")},4000);
#             }
#             let elementVisited = true;
#             let timeInterval = setInterval(function(){
#                 var iframeElem = $('#div-gpt-ad-1404818223391-0 iframe');
#                 if(elementVisited && iframeElem[0]){
#                     iframeElem[0].contentWindow.document.body.onclick =
#                     function() {
#                     window.dapCollector("trackLinkClick", "https://www.livemint.com/", "Livemint Homepage");
#                     elementVisited = false;
#                     }
#                 }
#             }, 1000);
#             setTimeout(function(){
#                 clearInterval(timeInterval);
#             }, 8000);
#         });
#         $(window).scroll(function(){
#             // This is then function used to detect if the element is scrolled into view
#             function elementScrolled(elem)
#             {
#                 var docViewTop = $(window).scrollTop();
#                 var docViewBottom = docViewTop + $(window).height();
#                 if($(elem) && $(elem).length >0){
#                     var elemTop = $(elem).offset().top;
#                     return ((elemTop <= docViewBottom) && (elemTop >= docViewTop));
#                 }
#                 return false;
#             }
#
#             // This is where we use the function to detect if ".box2" is scrolled into view, and when it is add the class ".animated" to the <p> child element
#             if(elementScrolled('#id_course_carousel_ul_container')) {
#                 var productSession = common.getSessionStorage('productCustomEvent');
#                 if (productSession == null) {
#                     fireCustomEventArray();
#                     common.setSessionStorage("productCustomEvent", 1);
#                 }
#             }
#         });
#   </script>
#   <script src="https://static1.shine.com/c/s1/js/client/web/indexPage.js">
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" class="lozad" data-src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1045809278/?value=0&amp;label=VNfsCJC81QMQ_pDX8gM&amp;guid=ON&amp;script=0" height="1" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TFD6PTW" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <script type="text/javascript">
#    $('.navbar-nav').on('mouseenter mouseleave', '.dropdown', function (e) {
#             var _d = $(e.target).closest('.dropdown');
#             if (e.type === 'mouseenter') _d.addClass('show');
#             setTimeout(function () {
#                 _d.toggleClass('show', _d.is(':hover'));
#                 $('[data-toggle="dropdown"]', _d).attr('aria-expanded', _d.is(':hover'));
#             }, 100);
#         });
#   </script>
#   <script>
#    $("#id_showform").on("click", function () {
#             $(".cls_withoutform").addClass('hide').removeClass("show");
#             $(".cls_withform").addClass('show').removeClass("hide");
#             $("#id_q").focus();
#             setTimeout(function () {
#                 $(".cls_search_jobs").addClass("show");
#             }, 10)
#         });
#         $("#id_hideform").on("click", function () {
#             $(".cls_withoutform").addClass('show').removeClass("hide");
#             $(".cls_withform").addClass('hide').removeClass("show");
#             $(".cls_search_jobs").removeClass("show");
#         });
#         lookupBinder.bindDropDown();
#         function fireCustomEventSingle(eventName,productName,productId,productPrice,productBrand,productCategory,productVariant,position,dimension1,dimension2,dimension3,actionField) {
#
#             arrayObject = [{
#                 name: productName,
#                 id: parseInt(productId, 10),
#                 price: productPrice,
#                 brand: productBrand,
#                 category: productCategory,
#                 variant: productVariant,
#                 position: parseInt(position, 10),
#                 dimension15: dimension1,
#                 dimension16: parseInt(dimension2, 10),
#                 dimension17: parseInt(dimension3, 10)
#             }]
#             try {
#                 window.dataLayer.push({
#                     event: eventName,
#                     ecommerce: {
#                         currencyCode: 'INR',
#                         click: {
#                             actionField: {
#                                 list: actionField
#                             },
#                             products: arrayObject
#                         }
#                     }
#                 });
#             } catch (e) {
#                 try {
#                     console.log(e);
#                 } catch (e) {}
#             }
#         }
#
#         function fireCustomEventArray() {
#             var data1 = [{'id': '3466', 'pHd': 'AI & Deep Learning with Tensor Flow', 'pURL': '/course/it-information-technology/ai-deep-learning-with-tensor-flow/pd-3466?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1549266081_7610.png', 'pBC': 9, 'pNJ': 10772, 'pPinb': 19995.0, 'pARx': '4.0', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '4317', 'pHd': 'AWS Architect Certification Training Combo', 'pURL': '/course/it-information-technology/aws-architect-certification-training-combo/pd-4317?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1564124425_1273.png', 'pBC': 21, 'pNJ': 44356, 'pPinb': 20995.0, 'pARx': '4.4', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '3416', 'pHd': 'Data Science with Python Certification Training Course', 'pURL': '/course/it-information-technology/data-science-with-python-certification-training-course/pd-3416?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1541158456_9921.png', 'pBC': 63, 'pNJ': 66098, 'pPinb': 21995.0, 'pARx': '4.5', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '4267', 'pHd': 'GST Practitioner Certification Course', 'pURL': '/course/banking-finance/gst-practitioner-certification-course/pd-4267?lc=1', 'pPvn': 'ISEL Global', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1561360226_4430.png', 'pBC': 385, 'pNJ': 12139, 'pPinb': 5700.0, 'pARx': '4.17', 'pCat': 'banking-finance', 'recommendation_by': 'static'}, {'id': '3394', 'pHd': 'Lean Six Sigma Expert Combo (GB + BB)', 'pURL': '/course/operation-management/lean-six-sigma-expert-combo-gb-bb/pd-3394?lc=1', 'pPvn': 'ISEL Global', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1536737243_2955.png', 'pBC': 376, 'pNJ': 11405, 'pPinb': 21000.0, 'pARx': '4.72', 'pCat': 'operation-management', 'recommendation_by': 'static'}];
#             var arrayObject = [];
#             data1.map( (jsonObject, index) => {
#                 arrayObject.push({
#                     name: jsonObject.pHd,
#                     id: parseInt(jsonObject.id, 10),
#                     price: parseInt(jsonObject.pPinb, 10),
#                     brand: jsonObject.pPvn,
#                     category: jsonObject.pCat,
#                     variant: 'Product',
#                     position: parseInt(index + 1, 10),
#                     dimension15: 'Homepage-Shine.com',
#                     dimension16: parseInt(jsonObject.pBC, 10),
#                     dimension17: parseInt(jsonObject.pNJ, 10),
#                     list: 'Our best selling Courses'
#                 });
#             });
#             try {
#                 window.dataLayer.push({
#                     event: 'productImpression',
#                     ecommerce: {
#                         currencyCode: 'INR',
#                         impressions: arrayObject
#                     }
#                 });
#             } catch (e) {
#                 try {
#                     console.log(e);
#                 } catch (e) {}
#             }
#         }
#   </script>
#   <script>
#    var carouselFunction = new carouselFn();
#   </script>
#   <script>
#    document.getElementById('id_course_carousel_ul_container').childNodes.forEach((item)=>{
#         if(item.id){
#             let id = item.id
#             touchpointTrackingMap[id]= function () {
#                 /*
#                 *   code to access data attached to dom and call api
#                 */
#                 let touchPointElement = document.getElementById(item.id);
#                 let { tid, tracking: trackingData, position, subproducts, source } = touchPointElement.dataset;
#                 position = position ? parseInt(position) : 0; // considering 0 position as default position
#                 learningTouchPointsTrackingApi(tid, 9, subproducts, 'seen', position, trackingData, source, false);
#                 return true;
#             };
#         }
#     })
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function(){
#             let randomAdsValue = Math.floor(Math.random() * 10) + 1;
#             if(randomAdsValue % 2 == 0){
#                 $('#id_banglore-banner').show();
#             }else {
#                 $('#id_hyderabad-banner').show();
#             }
#         })
#   </script>
#   <!-- Hotjar Tracking Code for https://www.shine.com/ -->
#   <script>
#    (function(h,o,t,j,a,r){
#             h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#             h._hjSettings={hjid:2630006,hjsv:6};
#             a=o.getElementsByTagName('head')[0];
#             r=o.createElement('script');r.async=1;
#             r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#  </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
  
URL = "https://www.monsterindia.com/"
r = requests.get(URL)
  
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://www.monsterindia.com/" on this server.
#   <p>
#    Reference #18.ac8c2c31.1644845421.7aa7e11
#   </p>
#  </body>
# </html>

# %%
soup.find_all(class_="outer-text")
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup
  
URL = "https://www.shine.com/"
r = requests.get(URL)
  
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Jobs 2022 - Search Jobs in India, Latest Job Vacancies, Recruitment - Shine.com
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="en-us" http-equiv="content-language"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="87369453667" property="fb:app_id"/>
#   <meta content="Shine" property="og:site_name"/>
#   <meta content="company" property="og:type"/>
#   <meta content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" property="og:image"/>
#   <meta content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" itemprop="image"/>
#   <link href="https://static1.shine.com/c/s1/images/favicon.ico" rel="SHORTCUT ICON"/>
#   <link href="https://www.shine.com/search.xml" rel="search" title="jobs on Shine.com" type="application/opensearchdescription+xml"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Shine.com is India's Leading Online Job and Recruitment Portal - Search &amp; Apply for Latest Job Vacancies across Top Companies in India. Register FREE Now!" name="description"/>
#   <meta content="Shine.com : One Stop Destination To Find Your Dream Job on the Go" property="og:title"/>
#   <meta content="job, jobs, job in india, job search, job vacancies, job openings, find jobs, shine, jobs for freshers, apply jobs" name="keywords"/>
#   <meta content="https://www.shine.com/" property="og:url"/>
#   <meta content="Fastest way to Manage your Job Search from your Mobile Anytime, Anywhere. Get Yourself Registered, Download the App and Get Referred in Top Companies in India" property="og:description"/>
#   <meta content="en-us" http-equiv="content-language"/>
#   <link href="https://fonts.googleapis.com/css?family=PT+Sans:400,700&amp;display=swap" rel="stylesheet"/>
#   <script>
#    /*! loadCSS. [c]2017 Filament Group, Inc. MIT License */
#         !function (a) { "use strict"; var b = function (b, c, d) { function j(a) { if (e.body) return a(); setTimeout(function () { j(a) }) } function l() { f.addEventListener && f.removeEventListener("load", l), f.media = d || "all" } var g, e = a.document, f = e.createElement("link"); if (c) g = c; else { var h = (e.body || e.getElementsByTagName("head")[0]).childNodes; g = h[h.length - 1] } var i = e.styleSheets; f.rel = "stylesheet", f.href = b, f.media = "only x", j(function () { g.parentNode.insertBefore(f, c ? g : g.nextSibling) }); var k = function (a) { for (var b = f.href, c = i.length; c--;)if (i[c].href === b) return a(); setTimeout(function () { k(a) }) }; return f.addEventListener && f.addEventListener("load", l), f.onloadcssdefined = k, k(l), f }; "undefined" != typeof exports ? exports.loadCSS = b : a.loadCSS = b }("undefined" != typeof global ? global : this);
#         /*! loadCSS rel=preload polyfill. [c]2017 Filament Group, Inc. MIT License */
#         !function (a) { if (a.loadCSS) { var b = loadCSS.relpreload = {}; if (b.support = function () { try { return a.document.createElement("link").relList.supports("preload") } catch (a) { return !1 } }, b.poly = function () { for (var b = a.document.getElementsByTagName("link"), c = 0; c < b.length; c++) { var d = b[c]; "preload" === d.rel && "style" === d.getAttribute("as") && (a.loadCSS(d.href, d, d.getAttribute("media")), d.rel = null) } }, !b.support()) { b.poly(); var c = a.setInterval(b.poly, 300); a.addEventListener && a.addEventListener("load", function () { b.poly(), a.clearInterval(c) }), a.attachEvent && a.attachEvent("onload", function () { a.clearInterval(c) }) } } }(this);
#   </script>
#   <link href="https://static1.shine.com/c/s1/CACHE/css/5b35a84869a4.css" rel="stylesheet" type="text/css"/>
#   <script>
#    /*<![CDATA[*/
#    var
#        sc = {};sc.showBlocker = '';sc.url_prefix = 'https://www.shine.com/';sc.url_prefix_media = "https://static1.shine.com/c/s1/";sc.url_prefix_images = "https://static1.shine.com/c/s1/"+'images/';sc.url_prefix_lookups = 'https://www.shine.com/'+'lookup/';sc.IsMidOut = '';sc.IsResumeMidOut = '';sc.next = '';sc.BounceStatus=0;sc.UID = 0;sc.LOGGEDIN = false;sc.MobileNo=0;sc.CountryCode='';sc.NAME = undefined;sc.FIRST_NAME = undefined;sc.LAST_NAME = undefined;sc.on_live = 1;sc.portal = 'recruiter';sc.CSRF_TOKEN='<input type="hidden" name="csrfmiddlewaretoken" value="DyDK827WpuuUWXxdqJek0t4ljQF3ivUU7yYw3jF4Af7wSeIIq0r4CEx2bdxOptrE">';sc.oldResume=0;sc.oldMobile=0;sc.itSkills=0;sc.androidApp=0;sc.incorrectFA=0;sc.incorrectMobile=0;sc.linkedin_apply_url='https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Fapply';sc.linkedin_login_url='https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Flogin';sc.url_prefix_withOutSlash=sc.url_prefix.slice(0,-1);sc.jobSeekerFlag='';sc.badProfile='';sc.clientData={};sc.clientData["currentSalaryL"]='';sc.clientData["currentSalT"]='';sc.clientData["currentExpY"]='';sc.clientData["currentExpM"]='';sc.truecaller_app_key='op5HY04fda58730dc418c8fb43a78543b7cba';sc.is_fresher=''; sc.learning_domain='https://learning.shine.com'; sc.learning_products_info={'application_highlighter': {'product_id': 4117, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4117&lc=1'}, 'shine_premium_1_month': {'product_id': 4573, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4573&lc=1'}, 'shine_premium_2_month': {'product_id': 4574, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4574&lc=1'}, 'profile_booster': {'product_id': 4561, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4561&lc=1'}, 'expert_help_0_to_1_year': {'product_id': 1921, 'url': 'https://resume.shine.com/product/freshers-level/1921?lc=1'}, 'expert_help_1_to_4_year': {'product_id': 1922, 'url': 'https://resume.shine.com/product/entry-level/1922?lc=1'}, 'expert_help_4_to_8_year': {'product_id': 1923, 'url': 'https://resume.shine.com/product/mid-level/1923?lc=1'}, 'expert_help_8_to_15_year': {'product_id': 1924, 'url': 'https://resume.shine.com/product/senior-level/1924?lc=1'}, 'expert_help_15_plus_year': {'product_id': 32, 'url': 'https://resume.shine.com/product/executive-level/32?lc=1'}, 'jobs_on_the_move': {'product_id': 3414, 'url': 'https://resume.shine.com/product/jobs-on-the-move-4/3414?lc=1'}, 'interview_preparation': {'product_id': 38, 'url': 'https://learning.shine.com/courses/personal-development/interview-preparation/38/?lc=1'}, 'resume_builder_1_year': {'product_id': 4527, 'url': 'https://resume.shine.com/product/resume-builder-1-year-rs-499/4527?lc=1'}, 'resume_builder_14_days': {'product_id': 4526, 'url': 'https://resume.shine.com/product/resume-builder-14-days-rs-199/4526?lc=1'}, 'featured_profile': {'product_id': 1939, 'url': 'https://resume.shine.com/product/featured-profile-10/1939?lc=1'}, 'linkedin_profile_0_to_1_year': {'product_id': 1926, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/entry-level-2/1926/?lc=1'}, 'linkedin_profile_1_to_4_year': {'product_id': 1925, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/fresher-level/1925/?lc=1'}, 'linkedin_profile_4_to_8_year': {'product_id': 1927, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/mid-level-2/1927/?lc=1'}, 'linkedin_profile_8_to_15_year': {'product_id': 1928, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/senior-level-2/1928/?lc=1'}, 'linkedin_profile_15_plus_year': {'product_id': 3 ...
#
# /*]]>*/
#   </script>
#   <script src="https://static1.shine.com/c/s1/CACHE/js/fcefed5c177c.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://static1.shine.com/c/s1/CACHE/js/ed5d7919f173.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    (function(p, l, o, w, i, n, g) {
#             if (!p[i]) {
#                 p.GlobalTrackerNamespace = p.GlobalTrackerNamespace || [];
#                 p.GlobalTrackerNamespace.push(i);
#                 p[i] = function() {
#                     (p[i].q = p[i].q || []).push(arguments);
#                 };
#                 p[i].q = p[i].q || [];
#                 n = l.createElement(o);
#                 g = l.getElementsByTagName(o)[0];
#                 n.async = 1;
#                 n.src = w;
#                 g.parentNode.insertBefore(n, g);
#                 p['platform'] = "web";
#             }
#         }
#         (window, document, "script", "https://analytics.htmedia.in/analytics-js/shinedap.js", "dapCollector"));
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3537905-1">
#   </script>
#   <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function () {
#             googletag.defineSlot('/1055314/sh_homepage_lhs_300x250', [300, 250], 'div-gpt-ad-1404815449201-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#             googletag.defineSlot('/1055314/Shine_HTNewsWidget_300x250', [300, 250], 'div-gpt-ad-1404818223391-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#             googletag.pubads().set("page_url", "https://www.shine.com/");//14425760768570183945
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().disableInitialLoad();
#             googletag.enableServices();
#         });
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function (w, d, s, l, i) {
#             w[l] = w[l] || []; w[l].push({
#                 'gtm.start':
#                     new Date().getTime(), event: 'gtm.js'
#             }); var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-TFD6PTW');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- ads handling script -->
#   <script data-cfasync="false" type="text/javascript">
#    (function(w, d) {
#         var s = d.createElement('script');
#         s.src = '//cdn.adpushup.com/42718/adpushup.js';
#         s.crossOrigin='anonymous';
#         s.type = 'text/javascript'; s.async = true;
#         (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s);
#         })(window, document);
#   </script>
#   <!-- End ads handling script -->
#   <script async="" data-ad-client="ca-pub-9783515403541006" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script type="application/ld+json">
#    {
#      "@context" : "http://schema.org",
#      "@type" : "Organization",
#      "name" : "Shine",
#      "url" : "https://www.shine.com",
#      "sameAs" : ["https://www.facebook.com/shinedotcom/", "https://twitter.com/Shinedotcom?lang=en", "https://plus.google.com/+shinecom", "https://www.youtube.com/user/ShineJobs", "https://www.linkedin.com/company/shinecom/" ]
#    }
#   </script>
#   <script type="text/javascript">
#    sc.LOGGEDIN = false;
#
#         //works when user is not logged in
#         function keepmeloggedin() {
#             try {
#                 var e = {};
#                 common.cookiename = "_kmsi_";
#                 e.c = common.readCookie();
#
#                 if (e.c != null && e.c != "") {
#                     e.d = e.c.replace(/"/g, "");
#                     if (e.d != void 0 && e.d != undefined && e.d != "undefined" && e.d.length > 1) {
#                         top.window.location = sc.url_prefix + "myshine/login/" + e.d + "/"
#                     }
#                 }
#             } catch (t) {
#             }
#         }
#         function redirectmyshinehome() {
#             common.cookiename = "_em_";
#             var e = {};
#             e.c = common.readCookie();
#             if (e.c != null && e.c != "" && e.c != "-1") {
#                 common.homepage = true;
#                 common.makeajax()
#             }
#         }
#         redirectmyshinehome();
#         keepmeloggedin();
#   </script>
#   <meta content="jzyKWIQOhsVNrHIxFkAVABnuY3HLZ4YNrV55n6Pt538" name="google-site-verification"/>
#  </head>
#  <body>
#   <div id="opaque">
#   </div>
#   <div class="container-fluid">
#    <div class="row">
#     <header class="pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2 fixed-top">
#      <nav class="navbar navbar-expand-sm navbar-dark navbar-inverse">
#       <!-- Brand -->
#       <a class="navbar-brand" href="#">
#       </a>
#       <!-- Links -->
#       <ul class="navbar-nav">
#        <li class="nav-item dropdown pr-2 pl-2">
#         <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs', 'Jobs in Top Cities, Jobs by Skills, Jobs by Courses, Jobs by Education, Jobs by Designation, Jobs by Company')">
#          Search Jobs
#         </a>
#         <div class="dropdown-menu sm-menu">
#          <a class="dropdown-item" href="/jobs-in-top-cities" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs in Top Cities')">
#           Jobs in Top Cities
#          </a>
#          <a class="dropdown-item" href="/jobs-by-skills" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Skills')">
#           Jobs by Skills
#          </a>
#          <a class="dropdown-item" href="/jobs-by-courses" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Courses')">
#           Jobs by Courses
#          </a>
#          <a class="dropdown-item" href="/jobs-by-education" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Education')">
#           Jobs by Education
#          </a>
#          <a class="dropdown-item" href="/jobs-by-designation" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Designation')">
#           Jobs by Designation
#          </a>
#          <!-- <a class="dropdown-item" href="/government-job-openings">Government Jobs</a>
#                         <a class="dropdown-item" href="/part-time-jobs">Part Time Jobs</a> -->
#          <a class="dropdown-item" href="/jobs-by-top-company" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Companies')">
#           Jobs by Companies
#          </a>
#         </div>
#        </li>
#        <li class="nav-item">
#        </li>
#        <li class="nav-item dropdown pr-2 pl-2">
#         <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="window.open('https://learning.shine.com/?utm_source=shine&amp;utm_medium=header'); MyGA.SendEvent('homepage_navigation','homepage_navigation','services', 'Digital Marketing, Data Science, Cloud Computing, GST, Prject Management, Six Sigma, Resume Writing, International Resume, LinkedIn Profile Writing, Jobs on the Move, Resume Formats, Resignation Letter Format')">
#          Services
#         </a>
#         <div class="dropdown-menu service_dropdown">
#          <div class="learning">
#           <strong>
#            E-learning
#           </strong>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/sales-and-marketing/digital-marketing/32/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Digital Marketing')">
#            Digital Marketing
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/it-information-technology/data-science/497/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Data Science')">
#            Data Science
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/it-information-technology/cloud-computing/82/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Cloud Computing')">
#            Cloud Computing
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/banking-finance/gst-2/507/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','GST')">
#            GST
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/operation-management/project-management/123/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Project Management')">
#            Project Management
#           </a>
#           <a class="dropdown-item" href="https://learning.shine.com/courses/operation-management/six-sigma/193/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Six Sigma')">
#            Six Sigma
#           </a>
#          </div>
#          <div class="learning">
#           <strong>
#            Resume Service
#           </strong>
#           <a class="dropdown-item" href="https://resume.shine.com/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resume Writing')">
#            Resume Writing
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/product/entry-level-freshers-4/2553?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','International Resume')">
#            International Resume
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/product/linkedin-profile-writing/entry-level-2/1926?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','LinkedIn Profile Writing')">
#            LinkedIn Profile Writing
#           </a>
#           <a class="dropdown-item" href="	https://resume.shine.com/product/jobs-on-the-move-4/3414?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Jobs on the Move')">
#            Jobs on the Move
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/cms/resume-format/1?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resume Formats')">
#            Resume Formats
#           </a>
#           <a class="dropdown-item" href="https://resume.shine.com/cms/resignation-letter-formats-samples/3/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resignation Letter Format')">
#            Resignation Letter Format
#           </a>
#          </div>
#         </div>
#        </li>
#        <!-- Dropdown -->
#        <li class="nav-item dropdown pr-2 pl-2">
#         <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources', 'Blog, Resume Tips, Career Help, Career Prospects, Job Search Guidance, Interview Tips')">
#          Resources
#         </a>
#         <div class="dropdown-menu">
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Blog')" target="_blank">
#           Blog
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/resume-tips/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Resume Tips')" target="_blank">
#           Resume Tips
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/career-help/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Career Help')" target="_blank">
#           Career Help
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/career-prospects/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Career Prospects')" target="_blank">
#           Career Prospects
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/job-search-guidance/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Job Search Guidance')" target="_blank">
#           Job Search Guidance
#          </a>
#          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/interview-tips/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Interview Tips')" target="_blank">
#           Interview Tips
#          </a>
#         </div>
#        </li>
#        <li class="nav-item pr-2 pl-2 br-round">
#         <a class="nav-link" href="https://recruiter.shine.com/?utm_source=shine&amp;utm_medium=header&amp;utm_campaign=CandidateHeader" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_recruiter')" title="Recruiter Zone">
#          Recruiter
#         </a>
#        </li>
#        <li class="nav-item pr-2 pl-2 br-round">
#         <a class="nav-link" href="/job-search/walkin-jobs" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_walkins')" title="Walk-ins">
#          Walk-ins
#         </a>
#        </li>
#        <li class="nav-item pr-2 pl-2 br-round covid">
#         <a class="nav-link" href="https://learning.shine.com/user-intent" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_covid-19_career_guide')" target="_blank">
#          Career Guidance
#          <sup>
#           NEW
#          </sup>
#         </a>
#        </li>
#       </ul>
#       <ul class="navbar-nav ml-auto">
#        <li class="nav-item">
#         <a class="nav-link outerborder pr-3 pl-3 mr-4" href="/free-job-alerts/" onclick="MyGA.SendEvent('homepage_jobalert_postajob','homepage_jobalert_postajob','click_jobalert','create job alert')">
#          Create job alert
#         </a>
#        </li>
#        <li class="nav-item">
#         <a class="nav-link outerborder pr-3 pl-3" href="https://recruiter.shine.com/online-package/offer/free-job-posting/?utm_source=shine&amp;utm_medium=header&amp;utm_campaign=CandidateHeader" onclick="MyGA.SendEvent('homepage_jobalert_postajob','homepage_jobalert_postajob','click_postajob','post a job')" title="Post a job">
#          Post a job
#         </a>
#        </li>
#        <li class="nav-item number pl-2">
#         080-47105555
#         <small>
#          9am - 6pm, Mon to Sat
#         </small>
#        </li>
#       </ul>
#      </nav>
#     </header>
#     <section class="home_mid container-fluid pt-4 cls_withoutform cls_form">
#      <div class="d-flex pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2 justify-content-between">
#       <div class="flex-row mt-1 pl-4 col-6">
#        <h1>
#         Growth on your mind?
#        </h1>
#        <h2>
#         Explore 300,000+ jobs
#        </h2>
#        <div class="inputstyle d-flex mt-4 p-4 align-items-center" id="id_showform">
#         Job title, skills
#        </div>
#       </div>
#       <div class="registration flex-row fl mt-2 p-5">
#        <a href="/registration/parser/" onclick="MyGA.SendEvent('homepage_login_register', 'homepage_login_register', 'click_register', 'register for free')">
#         <button class="btn btn-primary btn-yellow" type="button">
#          Register for free
#         </button>
#        </a>
#        <div class="sign_in pl-5 pt-4 ml-3">
#         <a class="cls_register_signin_homepage cls_login_header cls_call_dialogbox" data-category="signin" data-from="header" data-popuptype="4" href="/myshine/login/" onclick="MyGA.SendEvent('homepage_login_register', 'homepage_login_register', 'click_signin', 'sign in')" title="Jobseeker Login">
#          Sign in
#         </a>
#        </div>
#       </div>
#      </div>
#     </section>
#     <div class="home_mid_open pt-4 cls_form cls_withform hide">
#      <div class="d-flex pl-5 pr-5 justify-content-between">
#       <div class="flex-column mt-1 pl-4 col-12">
#        <h1 class="mb-3">
#         Growth on your mind?
#         <span class="close_form" id="id_hideform">
#         </span>
#        </h1>
#        <div class="hsearch d-flex flex-column flex-wrap">
#         <div class="advancsearch">
#          <form action="//www.shine.com/job-search/" class="cls_frm_reg_job_srch cls_txtanimation animation" data-errorcode="err_1" id="frm_adv_srch" method="post" novalidate="" onsubmit="common.stopBeforeJavascriptLoad(); searchAnalytics('frm_adv_srch', 'searchForm')">
#           <div class="cls_sel_serch_jobs cls_search_jobs search_left">
#            <ul>
#             <li class="key Kjob">
#              <label class="lbl">
#               Job title, skills
#              </label>
#              <input aria-label="Job title,skills" class="cls_input_validate cls_local_autocomplete search3" data-rulesid="01" data-selecttype="multiple" id="id_q" maxlength="150" name="q" required="" tabindex="0" type="text"/>
#             </li>
#             <li class="key homepageloc">
#              <label class="lbl">
#               Location
#              </label>
#              <input aria-label="Location" class="search3" id="id_loc" maxlength="150" name="loc" tabindex="0" type="text"/>
#             </li>
#             <li class="key key1 kexp">
#              <label class="lbl">
#               Experience
#              </label>
#              <select aria-label="Experience" class="styled cls_minval" id="id_minexp" name="minexp">
#               <option selected="" value="">
#                Experience (Years)
#               </option>
#              </select>
#             </li>
#            </ul>
#            <div class="clear">
#            </div>
#            <ul class="floatleft cls_ulAdvSearch" id="adv_srch" style="display: none;">
#             <li class="key key1 kexp1">
#              <label class="lbl">
#               Salary
#              </label>
#              <select aria-label="Salary" class="styled cls_minval" id="id_minsal" name="minsal">
#               <option selected="" value="">
#                Salary (Lakh/Year)
#               </option>
#              </select>
#             </li>
#             <li class="key key1 kexp1">
#              <label class="lbl">
#               Department
#              </label>
#              <select aria-label="Department" class="cls_input_validate styled" data-rulesid="01" id="id_area" name="area">
#               <option selected="" value="">
#                Department
#               </option>
#              </select>
#             </li>
#             <li class="key key1 kexp1" style="margin-right:none;">
#              <label class="lbl">
#               Industry
#              </label>
#              <select aria-label="Industry" class="cls_input_validate styled" data-rulesid="01" id="id_ind" name="ind">
#               <option selected="" value="">
#                Industry
#               </option>
#              </select>
#             </li>
#            </ul>
#            <li class="but1">
#             <input id="id_head_trigger_advSrch" name="advSrch" type="hidden" value="false"/>
#            </li>
#           </div>
#           <div class="expand" name="adv_srch">
#            <input aria-label="id_search_form" class="cls_btn_reg_job_srch cls_searchbtnabv submit" id="id_search_form" name="simplesearch" type="submit" value="Submit"/>
#            <a class="cls_ulAdvSearch_a" data-searchtype="adv_srch" href="javascript:void(0);">
#             <u>
#              Advanced search
#             </u>
#            </a>
#           </div>
#           <input id="formmd5" name="formmd5" type="hidden" value=""/>
#           <input id="id_best_matches" name="best_matches" type="hidden" value=""/>
#           <input id="id_posted_after" name="posted_after" type="hidden" value=""/>
#          </form>
#         </div>
#         <!--
# <input type="submit" value="" class="redbtn cls_btn_reg_job_srch_lrg" name="Submit" />
# -->
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--cool places to work start-->
#     <div class="flex-column mt-2 col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#      <h2 class="text-center">
#       Cool places to work
#      </h2>
#      <ul class="cool d-flex flex-row mt-3 justify-content-around">
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=497070&amp;next=https://recruiter.shine.com/micro-site/aditya-birla-group-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Aditya Birla Management Corporation Pvt. Ltd.')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/608a7830f65e4ac4a70869e145c55c25.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/449660b6ea5c4aada2e211f4831cc945.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=654568&amp;next=https://www.shine.com/job-search/teleperformance-global-services-pvt-ltd-openings?rect=654568" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Teleperformance Global Services Pvt Ltd,')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/d98a014b326648178fbb08eef46ac70e.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6c23dfb3c9224480870c900b8dddf299.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=677780&amp;next=https://www.shine.com/job-search/sbi-life-insurance-company-limited-openings?rect=677780" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','SBI Life Insurance Company Limited')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/7a22c70f27904e2e81d7ebd1066d55e1.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/17e4d7d8d2bf419eb023429afacb5154.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=532598&amp;next=https://recruiter.shine.com/micro-site/infosys-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Infosys Limited')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/26c83ce6d9df4733a9bbc06d2e3b8f0e.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/19b43e6c9ee345faa75540f998db7441.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#       <li class="p-3">
#        <figure>
#         <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=55437&amp;next=https://recruiter.shine.com/micro-site/genpact-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Genpact India Pvt Ltd')" target="_blank">
#          <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/c250bee50f5b490aac4b63fe281ab79e.png"/>
#          <span>
#           <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/4ba34994bc414de7984c38c9cee86ebe.png"/>
#          </span>
#         </a>
#        </figure>
#       </li>
#      </ul>
#     </div>
#     <!--cool places to work ends-->
#     <!--Top companies hiring starts-->
#     <div class="flex-column mt-4 mb-4 col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#      <h2 class="text-center pt-3">
#       Top companies hiring now
#      </h2>
#      <ul class="top_employer d-flex flex-row mb-5 mt-3 flex-wrap">
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=700272&amp;next=https://www.shine.com/job-search/reliance-nippon-life-insurance-company-limited-openings?rect=700272" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','RELIANCE NIPPON LIFE INSURANCE COMPANY LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/ab28f0af876f42cb96302faaea9e1671.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=699516&amp;next=https://recruiter.shine.com/micro-site/hewlett-packard-enterprise-jobs/" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Futurestep Recruitment Services Private Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/8ec12c71c03445248ec99942e16a812c.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=604202&amp;next=https://www.shine.com/job-search/yes-bank-ltd-openings?rect=604202" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Yes Bank Ltd')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/8b3d3868f9444657ad239ed43eb423b8.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=763688&amp;next=https://www.shine.com/job-search/tata-consultancy-services-limited-openings?rect=763688" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Tata Consultancy Services Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/b076fc83cebb42069205c9a410c9f618.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=735396&amp;next=https://www.shine.com/job-search/icici-bank-ltd-openings?rect=735396" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','ICICI Bank Ltd')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/9f53b7d4345d41ac9b657b726b6b3349.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=648608&amp;next=https://www.shine.com/job-search/aegis-customer-support-services-private-limited-openings?rect=648608" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Aegis Customer Support Services Private Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/da1f7501c8f740498dbb4b28fde081c2.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=700277&amp;next=https://www.shine.com/job-search/reliance-general-insurance-company-limited-openings?rect=700277" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','RELIANCE GENERAL INSURANCE COMPANY LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/f85756b6a88e4997beaf87c6f1bb5cfd.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=641256&amp;next=https://www.shine.com/job-search/cms-it-services-private-limited-openings?rect=641256" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','CMS IT SERVICES PRIVATE LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/f548e2c309c24db1a8b9d4ff9d97b02e.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=670803&amp;next=https://www.shine.com/job-search/tech-mahindra-ltd-openings?rect=670803" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Tech Mahindra Ltd.')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/a307d745fbbe46d3822e5b4e6f3fed55.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=683181&amp;next=https://www.shine.com/job-search/max-life-insurance-co-ltd-openings?rect=683181" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Max life insurance Co. LTD.')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6cf7d2611de84b7585d75db2f40e81b8.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=751515&amp;next=https://www.shine.com/job-search/d-mart-openings?rect=751515" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Avenue Supermarts Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/24d6c76bfae84a6f8bd18522f4744b3a.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=754750&amp;next=https://www.shine.com/job-search/byjus-openings?rect=754750" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','THINK &amp; LEARN PRIVATE LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/9b944622fc46422786322e57d29a4225.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=709489&amp;next=https://www.shine.com/job-search/steria-jobs" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Steria (India) Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/666b83a3c4974b4f92613fce536a4251.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=677780&amp;next=https://www.shine.com/job-search/sbi-life-insurance-company-limited-openings?rect=677780" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','SBI Life Insurance Company Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/7f5bc2c5010f4e0fbff014205842ff27.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=736552&amp;next=https://recruiter.shine.com/micro-site/indegene-private-limited-jobs/" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Indegene Private Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/700cc0d27c8b416bbfb9c2765652c9cd.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=739959&amp;next=https://www.shine.com/job-search/anand-rathi-share-and-stock-brokers-limited-openings?rect=739959" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','ANAND RATHI SHARE AND STOCK BROKERS LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/32ff5f1937b14c1d96212a1cfb563860.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=385010&amp;next=https://www.shine.com/job-search/quotes-kotak-mahindra-bank-limited-quotes-jobs?fcid=385010" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Kotak Mahindra Bank Limited')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/264470edd81541d190bc774a279534aa.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=101888&amp;next=https://www.shine.com/job-search/k12-techno-services-pvt-ltd-openings?rect=101888" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','K12 Techno Services Pvt. Ltd')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6f1e554cc7fd4ab89210fb651db329ea.png"/>
#        </a>
#       </li>
#       <li>
#        <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=745952&amp;next=https://www.shine.com/job-search/dbs-bank-india-limited-openings?rect=745952" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','DBS BANK INDIA LIMITED')" target="_blank">
#         <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/956bad7a7ab24728bff6ca4383565b29.png"/>
#        </a>
#       </li>
#      </ul>
#      <div class="white_button col-2">
#       <a href="/company-branding" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','view_all_top_companies')" target="_blank">
#        View all top companies
#       </a>
#      </div>
#     </div>
#     <!--Top companies hiring Ends-->
#     <!--Banner ad starts-->
#     <div class="container-fluid">
#      <div class="banner_container">
#       <div class="row">
#        <div class="d-flex mt-4 w-100 col-12 banner_mid_home">
#         <div>
#          <a href="https://amazonvirtualhiring.hirepro.in/registration/incta/ju0f4/apply/?j=56357&amp;e=12210" id="id_banglore-banner" style="display: none;">
#           <img class="lozad small_ad" data-src="https://static1.shine.com/c/s1/images/candidate/new/Amazon-Ad-Transaction-Risk-Investigator---SPRO-Hyderabad.gif" height="250" width="300"/>
#          </a>
#          <a href="https://amazonvirtualhiring.hirepro.in/registration/incta/ju0f4/apply/?j=56416&amp;e=12247" id="id_hyderabad-banner" style="display: none;">
#           <img class="lozad small_ad" data-src="https://static1.shine.com/c/s1/images/candidate/new/Amazon-Ad-Transaction-Risk-Investigator---SPRO-Bangalore.gif" height="250" width="300"/>
#          </a>
#         </div>
#         <div>
#          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=532598&amp;next=https://recruiter.shine.com/micro-site/infosys-jobs/restart-with-infosys/417/&amp;_ga=2.58698409.2024220180.1578306174-1942937461.1578306173" onclick="MyGA.SendEvent('homepage_ad', 'homepage_ad', 'click_recruiterad')" target="_blank">
#           <img class="lozad" data-src="https://static1.shine.com/c/s1/images/candidate/new/ad_banner_new1.png" height="250" width="779"/>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!--Banner ad Ends -->
#    </div>
#   </div>
#   <!--why shine starts-->
#   <div class="container-fluid mt-4">
#    <div class="row">
#     <div class="col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#      <div class="whyshine m-5">
#       <h2 class="text-center pt-5 pb4">
#        Why Shine
#       </h2>
#       <div class="d-flex justify-content-between pt-4">
#        <div class="flex-row candidates">
#         <p class="d-flex flex-column mt-2">
#          <strong class="d-flex flex-column">
#           3.4
#                                     crores+
#          </strong>
#          <span class="d-flex flex-column">
#           Candidates
#          </span>
#         </p>
#        </div>
#        <div class="flex-row jobs">
#         <p class="d-flex flex-column mt-2">
#          <strong class="d-flex flex-column">
#           300,000+
#          </strong>
#          <span class="d-flex flex-column">
#           Jobs
#          </span>
#         </p>
#        </div>
#        <div class="flex-row companies">
#         <p class="d-flex flex-column mt-3">
#          <strong class="d-flex flex-column">
#           15,000+
#          </strong>
#          <span class="d-flex flex-column">
#           Companies
#          </span>
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--why shine Ends -->
#   <div class="container-fluid premium_base">
#    <div class="graph_image_premium">
#    </div>
#    <a data-cartaddition="True" data-position="4" data-products="4" data-source="static" data-subproducts="None" data-tid="620a43c805e3fbf82d74fb7d" data-tracking='{"trigger_point": 13, "u_id": null}' id="id_shine_premium" onclick="redirectShinePremiumPage('620a43c805e3fbf82d74fb7d','{&quot;trigger_point&quot;: 13, &quot;u_id&quot;: null}','4', 'static');MyGA.SendEvent('homepage_premium', 'homepage_premium', 'click_getshinepremium')">
#     <div class="fasttrack-banner">
#      <span class="premium_crown">
#      </span>
#      <div class="fasttrack-banner_text">
#       <span class="shinepremium_head">
#        Shine Premium
#       </span>
#      </div>
#      <div class="shinepremium_content">
#       <span>
#        <strong>
#         Fastrack your job
#        </strong>
#        search with our premium services
#       </span>
#       <ul class="fastrack_banner_web">
#        <li>
#         Enhanced Profile
#        </li>
#        <li>
#         10x higher visibility to recruiters
#        </li>
#        <li>
#         Insights on other applicants
#        </li>
#        <li>
#         Interview Ready
#        </li>
#       </ul>
#       <div class="get-start-btn">
#        Get Shine Premium
#       </div>
#      </div>
#     </div>
#    </a>
#    <script>
#     window.touchpointTrackingMap && (touchpointTrackingMap.id_shine_premium = function() {
#         /*
# ...
#          Apply with Linkedin
#         </div>
#        </a>
#       </li>
#       <li class="msite_displaynone socialLogin">
#        <div class="social-login--btn google_button customBtn" data-actiontype="login" data-formtobesubmitted="id_applyWithGoogle" id="gSignInWrapper" onclick="MyGA.SendEvent('LoginPopup','Google')">
#         <div class="social-login--icon">
#          <i class="icon google">
#          </i>
#         </div>
#         <div class="social-login--text google msite_displaynone">
#          Apply with Google
#         </div>
#        </div>
#       </li>
#       <li class="msite_displaynone">
#        <div class="social-login--btn facebook_button" data-actiontype="login" data-formtobesubmitted="id_applyWithFB" id="id_loginWithFB" onclick="MyGA.SendEvent('LoginPopup','facebook')">
#         <div class="social-login--icon">
#          <i class="icon facebook">
#          </i>
#         </div>
#         <div class="social-login--text msite_displaynone">
#          Apply with Facebook
#         </div>
#        </div>
#       </li>
#      </ul>
#      <!----
#         Login with
#       -->
#      <ul class="cls_base_1 lgn_right lgn_right_linkedin social-login cls_social_login">
#       <li class="msite_displaynone socialLogin">
#        <div class="social-login--btn google_button customBtn" data-actiontype="login" data-formtobesubmitted="id_loginWithGoogle" id="gSignInWrapper" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','google')">
#         <div class="social-login--icon">
#          <i class="icon google">
#          </i>
#         </div>
#         <div class="social-login--text google msite_displaynone">
#          Sign-in with Google
#         </div>
#        </div>
#       </li>
#       <li class="recentsearches msite_displaynone socialLogin">
#        <a class="social-login--btn linkedin_button" href="https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Flogin" id="id_loginWithLinkedinUrl" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','Linkedin');">
#         <div class="social-login--icon">
#          <i class="icon linkedin">
#          </i>
#         </div>
#         <div class="social-login--text msite_displaynone">
#          Sign-in with Linkedin
#         </div>
#        </a>
#       </li>
#       <li class="msite_displaynone">
#        <div class="social-login--btn facebook_button" data-actiontype="login" data-formtobesubmitted="id_loginWithFbForm" id="id_loginWithFB" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','facebook')">
#         <div class="social-login--icon">
#          <i class="icon facebook">
#          </i>
#         </div>
#         <div class="social-login--text msite_displaynone">
#          Sign-in with Facebook
#         </div>
#        </div>
#       </li>
#       <!-- <li class="d-block text-center mt-4 regbtnText" style="width: 100%;">
#           Don't have Shine account?
#           <a href="/registration/parser/" class="white_button d-block col-7 mt-2 regBtn apply m-auto-temp"
#             onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','register now')"
#           >Register
#             now</a>
#         </li> -->
#      </ul>
#      <div class="cls_registernow register_bottom cls_base_1">
#       Don't have Shine account?
#       <a href="/registration/parser/" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','register now')">
#        Register
#             now
#       </a>
#      </div>
#      <div class="clearfix">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="forget_password modal standard_form_class" id="id_candidateforgotpassword" style="display: none;">
#    <div class="overlay">
#    </div>
#    <div class="modal_content">
#     <div class="modal_titlebar">
#      <span id="ui-id-1">
#       Forget Password
#      </span>
#      <a class="close" id="id_fpCancel">
#       <span class="">
#       </span>
#      </a>
#     </div>
#     <div class="" id="id_candidateforgotpassword">
#      <div class="forget m-4" id="id_fPForm">
#       <span>
#        Enter the Email ID with which you are registered on Shine.com
#       </span>
#       <form action="javascript:void(0);" id="id_forgotPassword" method="POST" novalidate="novalidate" onsubmit="return false">
#        <ul>
#         <li>
#          <input aria-label="Email Id" id="candidateemailid" name="email" placeholder="Email" type="text"/>
#         </li>
#        </ul>
#       </form>
#      </div>
#      <div id="id_successMsg_fp" style="display: none; padding-left: 5%">
#       A link to reset your Shine Password has been sent to your Email Id
#      </div>
#     </div>
#     <div class="popup_button_pannel">
#      <button class="highlight_button" id="id_fpSubmit" type="button">
#       Submit
#      </button>
#      <button class="highlight_button" id="id_fpCancelButton" style="display: none;" type="button">
#       Ok
#      </button>
#     </div>
#    </div>
#   </div>
#   <script src="https://apis.google.com/js/api:client.js">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#   </script>
#   <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js">
#   </script>
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <script src="https://static1.shine.com/c/s1/CACHE/js/9c4922e93e01.js" type="text/javascript">
#   </script>
#   <script src="https://static1.shine.com/c/s1/CACHE/js/ab53d675170b.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://static1.shine.com/c/s1/CACHE/js/98179a304fa6.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function () {
#             /* Page View Analytics Non Logged In */
#             // window.dapCollector('trackPageView', document.title);
#             let liveMintValue = "True";
#             if(liveMintValue == "True"){
#                 setTimeout(function(){window.dapCollector("trackImpression", "~", "vertical", 1, "Shine Homepage", "Livemint Homepage", "https://www.livemint.com/")},4000);
#             }
#             let elementVisited = true;
#             let timeInterval = setInterval(function(){
#                 var iframeElem = $('#div-gpt-ad-1404818223391-0 iframe');
#                 if(elementVisited && iframeElem[0]){
#                     iframeElem[0].contentWindow.document.body.onclick =
#                     function() {
#                     window.dapCollector("trackLinkClick", "https://www.livemint.com/", "Livemint Homepage");
#                     elementVisited = false;
#                     }
#                 }
#             }, 1000);
#             setTimeout(function(){
#                 clearInterval(timeInterval);
#             }, 8000);
#         });
#         $(window).scroll(function(){
#             // This is then function used to detect if the element is scrolled into view
#             function elementScrolled(elem)
#             {
#                 var docViewTop = $(window).scrollTop();
#                 var docViewBottom = docViewTop + $(window).height();
#                 if($(elem) && $(elem).length >0){
#                     var elemTop = $(elem).offset().top;
#                     return ((elemTop <= docViewBottom) && (elemTop >= docViewTop));
#                 }
#                 return false;
#             }
#
#             // This is where we use the function to detect if ".box2" is scrolled into view, and when it is add the class ".animated" to the <p> child element
#             if(elementScrolled('#id_course_carousel_ul_container')) {
#                 var productSession = common.getSessionStorage('productCustomEvent');
#                 if (productSession == null) {
#                     fireCustomEventArray();
#                     common.setSessionStorage("productCustomEvent", 1);
#                 }
#             }
#         });
#   </script>
#   <script src="https://static1.shine.com/c/s1/js/client/web/indexPage.js">
#   </script>
#   <script src="//www.googleadservices.com/pagead/conversion.js">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" class="lozad" data-src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1045809278/?value=0&amp;label=VNfsCJC81QMQ_pDX8gM&amp;guid=ON&amp;script=0" height="1" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TFD6PTW" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <script type="text/javascript">
#    $('.navbar-nav').on('mouseenter mouseleave', '.dropdown', function (e) {
#             var _d = $(e.target).closest('.dropdown');
#             if (e.type === 'mouseenter') _d.addClass('show');
#             setTimeout(function () {
#                 _d.toggleClass('show', _d.is(':hover'));
#                 $('[data-toggle="dropdown"]', _d).attr('aria-expanded', _d.is(':hover'));
#             }, 100);
#         });
#   </script>
#   <script>
#    $("#id_showform").on("click", function () {
#             $(".cls_withoutform").addClass('hide').removeClass("show");
#             $(".cls_withform").addClass('show').removeClass("hide");
#             $("#id_q").focus();
#             setTimeout(function () {
#                 $(".cls_search_jobs").addClass("show");
#             }, 10)
#         });
#         $("#id_hideform").on("click", function () {
#             $(".cls_withoutform").addClass('show').removeClass("hide");
#             $(".cls_withform").addClass('hide').removeClass("show");
#             $(".cls_search_jobs").removeClass("show");
#         });
#         lookupBinder.bindDropDown();
#         function fireCustomEventSingle(eventName,productName,productId,productPrice,productBrand,productCategory,productVariant,position,dimension1,dimension2,dimension3,actionField) {
#
#             arrayObject = [{
#                 name: productName,
#                 id: parseInt(productId, 10),
#                 price: productPrice,
#                 brand: productBrand,
#                 category: productCategory,
#                 variant: productVariant,
#                 position: parseInt(position, 10),
#                 dimension15: dimension1,
#                 dimension16: parseInt(dimension2, 10),
#                 dimension17: parseInt(dimension3, 10)
#             }]
#             try {
#                 window.dataLayer.push({
#                     event: eventName,
#                     ecommerce: {
#                         currencyCode: 'INR',
#                         click: {
#                             actionField: {
#                                 list: actionField
#                             },
#                             products: arrayObject
#                         }
#                     }
#                 });
#             } catch (e) {
#                 try {
#                     console.log(e);
#                 } catch (e) {}
#             }
#         }
#
#         function fireCustomEventArray() {
#             var data1 = [{'id': '3466', 'pHd': 'AI & Deep Learning with Tensor Flow', 'pURL': '/course/it-information-technology/ai-deep-learning-with-tensor-flow/pd-3466?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1549266081_7610.png', 'pBC': 9, 'pNJ': 10772, 'pPinb': 19995.0, 'pARx': '4.0', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '4317', 'pHd': 'AWS Architect Certification Training Combo', 'pURL': '/course/it-information-technology/aws-architect-certification-training-combo/pd-4317?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1564124425_1273.png', 'pBC': 21, 'pNJ': 44356, 'pPinb': 20995.0, 'pARx': '4.4', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '3416', 'pHd': 'Data Science with Python Certification Training Course', 'pURL': '/course/it-information-technology/data-science-with-python-certification-training-course/pd-3416?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1541158456_9921.png', 'pBC': 63, 'pNJ': 66098, 'pPinb': 21995.0, 'pARx': '4.5', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '4267', 'pHd': 'GST Practitioner Certification Course', 'pURL': '/course/banking-finance/gst-practitioner-certification-course/pd-4267?lc=1', 'pPvn': 'ISEL Global', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1561360226_4430.png', 'pBC': 385, 'pNJ': 12139, 'pPinb': 5700.0, 'pARx': '4.17', 'pCat': 'banking-finance', 'recommendation_by': 'static'}, {'id': '3394', 'pHd': 'Lean Six Sigma Expert Combo (GB + BB)', 'pURL': '/course/operation-management/lean-six-sigma-expert-combo-gb-bb/pd-3394?lc=1', 'pPvn': 'ISEL Global', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1536737243_2955.png', 'pBC': 376, 'pNJ': 11405, 'pPinb': 21000.0, 'pARx': '4.72', 'pCat': 'operation-management', 'recommendation_by': 'static'}];
#             var arrayObject = [];
#             data1.map( (jsonObject, index) => {
#                 arrayObject.push({
#                     name: jsonObject.pHd,
#                     id: parseInt(jsonObject.id, 10),
#                     price: parseInt(jsonObject.pPinb, 10),
#                     brand: jsonObject.pPvn,
#                     category: jsonObject.pCat,
#                     variant: 'Product',
#                     position: parseInt(index + 1, 10),
#                     dimension15: 'Homepage-Shine.com',
#                     dimension16: parseInt(jsonObject.pBC, 10),
#                     dimension17: parseInt(jsonObject.pNJ, 10),
#                     list: 'Our best selling Courses'
#                 });
#             });
#             try {
#                 window.dataLayer.push({
#                     event: 'productImpression',
#                     ecommerce: {
#                         currencyCode: 'INR',
#                         impressions: arrayObject
#                     }
#                 });
#             } catch (e) {
#                 try {
#                     console.log(e);
#                 } catch (e) {}
#             }
#         }
#   </script>
#   <script>
#    var carouselFunction = new carouselFn();
#   </script>
#   <script>
#    document.getElementById('id_course_carousel_ul_container').childNodes.forEach((item)=>{
#         if(item.id){
#             let id = item.id
#             touchpointTrackingMap[id]= function () {
#                 /*
#                 *   code to access data attached to dom and call api
#                 */
#                 let touchPointElement = document.getElementById(item.id);
#                 let { tid, tracking: trackingData, position, subproducts, source } = touchPointElement.dataset;
#                 position = position ? parseInt(position) : 0; // considering 0 position as default position
#                 learningTouchPointsTrackingApi(tid, 9, subproducts, 'seen', position, trackingData, source, false);
#                 return true;
#             };
#         }
#     })
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function(){
#             let randomAdsValue = Math.floor(Math.random() * 10) + 1;
#             if(randomAdsValue % 2 == 0){
#                 $('#id_banglore-banner').show();
#             }else {
#                 $('#id_hyderabad-banner').show();
#             }
#         })
#   </script>
#   <!-- Hotjar Tracking Code for https://www.shine.com/ -->
#   <script>
#    (function(h,o,t,j,a,r){
#             h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#             h._hjSettings={hjid:2630006,hjsv:6};
#             a=o.getElementsByTagName('head')[0];
#             r=o.createElement('script');r.async=1;
#             r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#             a.appendChild(r);
#         })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#  </body>
# </html>

# %%
soup.find('p')
# Out:
# <p class="d-flex flex-column mt-2"><strong class="d-flex flex-column">3.4
#                                     crores+</strong><span class="d-flex flex-column">Candidates</span></p>

# %%
list(soup.children)
# Out:
# ['html',
#  <html lang="en"><head>
#      <title>Jobs 2022 - Search Jobs in India, Latest Job Vacancies, Recruitment - Shine.com</title>
#      <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#      <meta content="en-us" http-equiv="content-language"/>
#      <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#      <meta content="87369453667" property="fb:app_id"/>
#      <meta content="Shine" property="og:site_name"/>
#      <meta content="company" property="og:type"/>
#      <meta content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" property="og:image"/>
#      <meta content="https://static1.shine.com/c/s1/images/candidate/new/NewShinelogo.gif" itemprop="image"/>
#      <link href="https://static1.shine.com/c/s1/images/favicon.ico" rel="SHORTCUT ICON"/>
#      <link href="https://www.shine.com/search.xml" rel="search" title="jobs on Shine.com" type="application/opensearchdescription+xml"/>
#      <meta content="width=device-width, initial-scale=1" name="viewport"/>
#      <meta content="Shine.com is India's Leading Online Job and Recruitment Portal - Search &amp; Apply for Latest Job Vacancies across Top Companies in India. Register FREE Now!" name="description"/>
#      <meta content="Shine.com : One Stop Destination To Find Your Dream Job on the Go" property="og:title"/>
#      <meta content="job, jobs, job in india, job search, job vacancies, job openings, find jobs, shine, jobs for freshers, apply jobs" name="keywords"/>
#      <meta content="https://www.shine.com/" property="og:url"/>
#      <meta content="Fastest way to Manage your Job Search from your Mobile Anytime, Anywhere. Get Yourself Registered, Download the App and Get Referred in Top Companies in India" property="og:description"/>
#      <meta content="en-us" http-equiv="content-language"/>
#      <link href="https://fonts.googleapis.com/css?family=PT+Sans:400,700&amp;display=swap" rel="stylesheet"/>
#      <script>
#          /*! loadCSS. [c]2017 Filament Group, Inc. MIT License */
#          !function (a) { "use strict"; var b = function (b, c, d) { function j(a) { if (e.body) return a(); setTimeout(function () { j(a) }) } function l() { f.addEventListener && f.removeEventListener("load", l), f.media = d || "all" } var g, e = a.document, f = e.createElement("link"); if (c) g = c; else { var h = (e.body || e.getElementsByTagName("head")[0]).childNodes; g = h[h.length - 1] } var i = e.styleSheets; f.rel = "stylesheet", f.href = b, f.media = "only x", j(function () { g.parentNode.insertBefore(f, c ? g : g.nextSibling) }); var k = function (a) { for (var b = f.href, c = i.length; c--;)if (i[c].href === b) return a(); setTimeout(function () { k(a) }) }; return f.addEventListener && f.addEventListener("load", l), f.onloadcssdefined = k, k(l), f }; "undefined" != typeof exports ? exports.loadCSS = b : a.loadCSS = b }("undefined" != typeof global ? global : this);
#          /*! loadCSS rel=preload polyfill. [c]2017 Filament Group, Inc. MIT License */
#          !function (a) { if (a.loadCSS) { var b = loadCSS.relpreload = {}; if (b.support = function () { try { return a.document.createElement("link").relList.supports("preload") } catch (a) { return !1 } }, b.poly = function () { for (var b = a.document.getElementsByTagName("link"), c = 0; c < b.length; c++) { var d = b[c]; "preload" === d.rel && "style" === d.getAttribute("as") && (a.loadCSS(d.href, d, d.getAttribute("media")), d.rel = null) } }, !b.support()) { b.poly(); var c = a.setInterval(b.poly, 300); a.addEventListener && a.addEventListener("load", function () { b.poly(), a.clearInterval(c) }), a.attachEvent && a.attachEvent("onload", function () { a.clearInterval(c) }) } } }(this);
#      </script>
#      <link href="https://static1.shine.com/c/s1/CACHE/css/5b35a84869a4.css" rel="stylesheet" type="text/css"/>
#
#
#  <script>/*<![CDATA[*/
#     var
#         sc = {};sc.showBlocker = '';sc.url_prefix = 'https://www.shine.com/';sc.url_prefix_media = "https://static1.shine.com/c/s1/";sc.url_prefix_images = "https://static1.shine.com/c/s1/"+'images/';sc.url_prefix_lookups = 'https://www.shine.com/'+'lookup/';sc.IsMidOut = '';sc.IsResumeMidOut = '';sc.next = '';sc.BounceStatus=0;sc.UID = 0;sc.LOGGEDIN = false;sc.MobileNo=0;sc.CountryCode='';sc.NAME = undefined;sc.FIRST_NAME = undefined;sc.LAST_NAME = undefined;sc.on_live = 1;sc.portal = 'recruiter';sc.CSRF_TOKEN='<input type="hidden" name="csrfmiddlewaretoken" value="DyDK827WpuuUWXxdqJek0t4ljQF3ivUU7yYw3jF4Af7wSeIIq0r4CEx2bdxOptrE">';sc.oldResume=0;sc.oldMobile=0;sc.itSkills=0;sc.androidApp=0;sc.incorrectFA=0;sc.incorrectMobile=0;sc.linkedin_apply_url='https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Fapply';sc.linkedin_login_url='https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Flogin';sc.url_prefix_withOutSlash=sc.url_prefix.slice(0,-1);sc.jobSeekerFlag='';sc.badProfile='';sc.clientData={};sc.clientData["currentSalaryL"]='';sc.clientData["currentSalT"]='';sc.clientData["currentExpY"]='';sc.clientData["currentExpM"]='';sc.truecaller_app_key='op5HY04fda58730dc418c8fb43a78543b7cba';sc.is_fresher=''; sc.learning_domain='https://learning.shine.com'; sc.learning_products_info={'application_highlighter': {'product_id': 4117, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4117&lc=1'}, 'shine_premium_1_month': {'product_id': 4573, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4573&lc=1'}, 'shine_premium_2_month': {'product_id': 4574, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4574&lc=1'}, 'profile_booster': {'product_id': 4561, 'url': 'https://resume.shine.com/cart/payment-summary/?prod_id=4561&lc=1'}, 'expert_help_0_to_1_year': {'product_id': 1921, 'url': 'https://resume.shine.com/product/freshers-level/1921?lc=1'}, 'expert_help_1_to_4_year': {'product_id': 1922, 'url': 'https://resume.shine.com/product/entry-level/1922?lc=1'}, 'expert_help_4_to_8_year': {'product_id': 1923, 'url': 'https://resume.shine.com/product/mid-level/1923?lc=1'}, 'expert_help_8_to_15_year': {'product_id': 1924, 'url': 'https://resume.shine.com/product/senior-level/1924?lc=1'}, 'expert_help_15_plus_year': {'product_id': 32, 'url': 'https://resume.shine.com/product/executive-level/32?lc=1'}, 'jobs_on_the_move': {'product_id': 3414, 'url': 'https://resume.shine.com/product/jobs-on-the-move-4/3414?lc=1'}, 'interview_preparation': {'product_id': 38, 'url': 'https://learning.shine.com/courses/personal-development/interview-preparation/38/?lc=1'}, 'resume_builder_1_year': {'product_id': 4527, 'url': 'https://resume.shine.com/product/resume-builder-1-year-rs-499/4527?lc=1'}, 'resume_builder_14_days': {'product_id': 4526, 'url': 'https://resume.shine.com/product/resume-builder-14-days-rs-199/4526?lc=1'}, 'featured_profile': {'product_id': 1939, 'url': 'https://resume.shine.com/product/featured-profile-10/1939?lc=1'}, 'linkedin_profile_0_to_1_year': {'product_id': 1926, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/entry-level-2/1926/?lc=1'}, 'linkedin_profile_1_to_4_year': {'product_id': 1925, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/fresher-level/1925/?lc=1'}, 'linkedin_profile_4_to_8_year': {'product_id': 1927, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/mid-level-2/1927/?lc=1'}, 'linkedin_profile_8_to_15_year': {'product_id': 1928, 'url': 'https://resume.shine.com/product/linkedin-profile-writing/senior-level-2/1928/?lc=1'}, 'linkedin_profile_15_plus_year': {'product_id':  ...
#
#  /*]]>*/</script>
#
#      <script src="https://static1.shine.com/c/s1/CACHE/js/fcefed5c177c.js" type="text/javascript"></script>
#  <script defer="" src="https://static1.shine.com/c/s1/CACHE/js/ed5d7919f173.js" type="text/javascript"></script>
#
#
#      <script type="text/javascript">
#          (function(p, l, o, w, i, n, g) {
#              if (!p[i]) {
#                  p.GlobalTrackerNamespace = p.GlobalTrackerNamespace || [];
#                  p.GlobalTrackerNamespace.push(i);
#                  p[i] = function() {
#                      (p[i].q = p[i].q || []).push(arguments);
#                  };
#                  p[i].q = p[i].q || [];
#                  n = l.createElement(o);
#                  g = l.getElementsByTagName(o)[0];
#                  n.async = 1;
#                  n.src = w;
#                  g.parentNode.insertBefore(n, g);
#                  p['platform'] = "web";
#              }
#          }
#          (window, document, "script", "https://analytics.htmedia.in/analytics-js/shinedap.js", "dapCollector"));
#      </script>
#
#      <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-3537905-1"></script>
#
#
#      <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
#      <script>
#          var googletag = googletag || {};
#          googletag.cmd = googletag.cmd || [];
#      </script>
#      <script type="text/javascript">
#          googletag.cmd.push(function () {
#              googletag.defineSlot('/1055314/sh_homepage_lhs_300x250', [300, 250], 'div-gpt-ad-1404815449201-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#              googletag.defineSlot('/1055314/Shine_HTNewsWidget_300x250', [300, 250], 'div-gpt-ad-1404818223391-0').addService(googletag.pubads()).setCollapseEmptyDiv(true, true);
#              googletag.pubads().set("page_url", "https://www.shine.com/");//14425760768570183945
#              googletag.pubads().enableSingleRequest();
#              googletag.pubads().disableInitialLoad();
#              googletag.enableServices();
#          });
#      </script>
#
#
#
#
#      <!-- Google Tag Manager -->
#      <script>(function (w, d, s, l, i) {
#              w[l] = w[l] || []; w[l].push({
#                  'gtm.start':
#                      new Date().getTime(), event: 'gtm.js'
#              }); var f = d.getElementsByTagName(s)[0],
#                  j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                      'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#          })(window, document, 'script', 'dataLayer', 'GTM-TFD6PTW');</script>
#      <!-- End Google Tag Manager -->
#
#
#      <!-- ads handling script -->
#
#      <script data-cfasync="false" type="text/javascript">
#          (function(w, d) {
#          var s = d.createElement('script');
#          s.src = '//cdn.adpushup.com/42718/adpushup.js';
#          s.crossOrigin='anonymous';
#          s.type = 'text/javascript'; s.async = true;
#          (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s);
#          })(window, document);
#          </script>
#
#      <!-- End ads handling script -->
#
#
#
#          <script async="" data-ad-client="ca-pub-9783515403541006" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#
#
#      <script type="application/ld+json">
#     {
#       "@context" : "http://schema.org",
#       "@type" : "Organization",
#       "name" : "Shine",
#       "url" : "https://www.shine.com",
#       "sameAs" : ["https://www.facebook.com/shinedotcom/", "https://twitter.com/Shinedotcom?lang=en", "https://plus.google.com/+shinecom", "https://www.youtube.com/user/ShineJobs", "https://www.linkedin.com/company/shinecom/" ]
#     }
#
#          </script>
#      <script type="text/javascript">
#          sc.LOGGEDIN = false;
#
#          //works when user is not logged in
#          function keepmeloggedin() {
#              try {
#                  var e = {};
#                  common.cookiename = "_kmsi_";
#                  e.c = common.readCookie();
#
#                  if (e.c != null && e.c != "") {
#                      e.d = e.c.replace(/"/g, "");
#                      if (e.d != void 0 && e.d != undefined && e.d != "undefined" && e.d.length > 1) {
#                          top.window.location = sc.url_prefix + "myshine/login/" + e.d + "/"
#                      }
#                  }
#              } catch (t) {
#              }
#          }
#          function redirectmyshinehome() {
#              common.cookiename = "_em_";
#              var e = {};
#              e.c = common.readCookie();
#              if (e.c != null && e.c != "" && e.c != "-1") {
#                  common.homepage = true;
#                  common.makeajax()
#              }
#          }
#          redirectmyshinehome();
#          keepmeloggedin();
#      </script>
#      <meta content="jzyKWIQOhsVNrHIxFkAVABnuY3HLZ4YNrV55n6Pt538" name="google-site-verification"/>
#  </head>
#
#  <body>
#      <div id="opaque"></div>
#      <div class="container-fluid">
#          <div class="row">
#
#
#
#
#
#  <header class="pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2 fixed-top">
#          <nav class="navbar navbar-expand-sm navbar-dark navbar-inverse">
#              <!-- Brand -->
#              <a class="navbar-brand" href="#"></a>
#              <!-- Links -->
#              <ul class="navbar-nav">
#                  <li class="nav-item dropdown pr-2 pl-2">
#                      <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs', 'Jobs in Top Cities, Jobs by Skills, Jobs by Courses, Jobs by Education, Jobs by Designation, Jobs by Company')">
#                          Search Jobs
#                      </a>
#                      <div class="dropdown-menu sm-menu">
#                          <a class="dropdown-item" href="/jobs-in-top-cities" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs in Top Cities')">Jobs in Top Cities</a>
#                          <a class="dropdown-item" href="/jobs-by-skills" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Skills')">Jobs by Skills</a>
#                          <a class="dropdown-item" href="/jobs-by-courses" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Courses')">Jobs by Courses</a>
#                          <a class="dropdown-item" href="/jobs-by-education" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Education')">Jobs by Education</a>
#                          <a class="dropdown-item" href="/jobs-by-designation" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Designation')">Jobs by Designation</a>
#                          <!-- <a class="dropdown-item" href="/government-job-openings">Government Jobs</a>
#                          <a class="dropdown-item" href="/part-time-jobs">Part Time Jobs</a> -->
#                          <a class="dropdown-item" href="/jobs-by-top-company" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','search_jobs','Jobs by Companies')">Jobs by Companies</a>
#                      </div>
#                  </li>
#                  <li class="nav-item">
#                  </li><li class="nav-item dropdown pr-2 pl-2">
#                      <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="window.open('https://learning.shine.com/?utm_source=shine&amp;utm_medium=header'); MyGA.SendEvent('homepage_navigation','homepage_navigation','services', 'Digital Marketing, Data Science, Cloud Computing, GST, Prject Management, Six Sigma, Resume Writing, International Resume, LinkedIn Profile Writing, Jobs on the Move, Resume Formats, Resignation Letter Format')">
#                          Services </a>
#                      <div class="dropdown-menu service_dropdown">
#                          <div class="learning">
#                              <strong>E-learning</strong>
#                              <a class="dropdown-item" href="https://learning.shine.com/courses/sales-and-marketing/digital-marketing/32/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Digital Marketing')">Digital Marketing</a>
#                              <a class="dropdown-item" href="https://learning.shine.com/courses/it-information-technology/data-science/497/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Data Science')">Data Science</a>
#                              <a class="dropdown-item" href="https://learning.shine.com/courses/it-information-technology/cloud-computing/82/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Cloud Computing')">Cloud Computing</a>
#                              <a class="dropdown-item" href="https://learning.shine.com/courses/banking-finance/gst-2/507/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','GST')">GST</a>
#                              <a class="dropdown-item" href="https://learning.shine.com/courses/operation-management/project-management/123/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Project Management')">Project Management</a>
#                              <a class="dropdown-item" href="https://learning.shine.com/courses/operation-management/six-sigma/193/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','services','Six Sigma')">Six Sigma</a>
#                      </div>
#                      <div class="learning">
#                          <strong>Resume Service</strong>
#                          <a class="dropdown-item" href="https://resume.shine.com/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resume Writing')">Resume Writing</a>
#                          <a class="dropdown-item" href="https://resume.shine.com/product/entry-level-freshers-4/2553?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','International Resume')">International Resume</a>
#                          <a class="dropdown-item" href="https://resume.shine.com/product/linkedin-profile-writing/entry-level-2/1926?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','LinkedIn Profile Writing')">LinkedIn Profile Writing</a>
#                          <a class="dropdown-item" href="	https://resume.shine.com/product/jobs-on-the-move-4/3414?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Jobs on the Move')">Jobs on the Move</a>
#                          <a class="dropdown-item" href="https://resume.shine.com/cms/resume-format/1?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resume Formats')">Resume Formats</a>
#                          <a class="dropdown-item" href="https://resume.shine.com/cms/resignation-letter-formats-samples/3/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resume_services','Resignation Letter Format')">Resignation Letter Format</a>
#                      </div>
#                      </div>
#                  </li>
#
#                  <!-- Dropdown -->
#                  <li class="nav-item dropdown pr-2 pl-2">
#                      <a class="nav-link dropdown-toggle" data-toggle="dropdown" href="javascript:void(0)" id="navbardrop" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources', 'Blog, Resume Tips, Career Help, Career Prospects, Job Search Guidance, Interview Tips')">
#                          Resources </a>
#                      <div class="dropdown-menu">
#                          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Blog')" target="_blank">Blog</a>
#                          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/resume-tips/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Resume Tips')" target="_blank">Resume Tips</a>
#                          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/career-help/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Career Help')" target="_blank">Career Help</a>
#                          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/career-prospects/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Career Prospects')" target="_blank">Career Prospects</a>
#                          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/job-search-guidance/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Job Search Guidance')" target="_blank">Job Search Guidance</a>
#                          <a class="dropdown-item" href="https://learning.shine.com/talenteconomy/interview-tips/?utm_source=shine&amp;utm_medium=nav_bar" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','resources','Interview Tips')" target="_blank">Interview Tips</a>
#                      </div>
#                  </li>
#                  <li class="nav-item pr-2 pl-2 br-round">
#                      <a class="nav-link" href="https://recruiter.shine.com/?utm_source=shine&amp;utm_medium=header&amp;utm_campaign=CandidateHeader" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_recruiter')" title="Recruiter Zone">Recruiter</a>
#                  </li>
#                  <li class="nav-item pr-2 pl-2 br-round">
#                      <a class="nav-link" href="/job-search/walkin-jobs" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_walkins')" title="Walk-ins">Walk-ins</a>
#                  </li>
#                  <li class="nav-item pr-2 pl-2 br-round covid">
#                      <a class="nav-link" href="https://learning.shine.com/user-intent" onclick="MyGA.SendEvent('homepage_navigation','homepage_navigation','click_covid-19_career_guide')" target="_blank">Career Guidance<sup>
#                          NEW
#                      </sup></a>
#                  </li>
#
#              </ul>
#              <ul class="navbar-nav ml-auto">
#                  <li class="nav-item">
#              <a class="nav-link outerborder pr-3 pl-3 mr-4" href="/free-job-alerts/" onclick="MyGA.SendEvent('homepage_jobalert_postajob','homepage_jobalert_postajob','click_jobalert','create job alert')">Create job alert</a>
#                  </li>
#                  <li class="nav-item">
#                      <a class="nav-link outerborder pr-3 pl-3" href="https://recruiter.shine.com/online-package/offer/free-job-posting/?utm_source=shine&amp;utm_medium=header&amp;utm_campaign=CandidateHeader" onclick="MyGA.SendEvent('homepage_jobalert_postajob','homepage_jobalert_postajob','click_postajob','post a job')" title="Post a job">Post a job</a>
#                  </li>
#                  <li class="nav-item number pl-2">080-47105555
#                      <small>9am - 6pm, Mon to Sat </small></li>
#              </ul>
#          </nav>
#      </header>
#
#              <section class="home_mid container-fluid pt-4 cls_withoutform cls_form">
#                  <div class="d-flex pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2 justify-content-between">
#                      <div class="flex-row mt-1 pl-4 col-6">
#                          <h1>Growth on your mind?</h1>
#                          <h2>Explore 300,000+ jobs</h2>
#                          <div class="inputstyle d-flex mt-4 p-4 align-items-center" id="id_showform">Job title, skills
#                          </div>
#                      </div>
#                      <div class="registration flex-row fl mt-2 p-5">
#                          <a href="/registration/parser/" onclick="MyGA.SendEvent('homepage_login_register', 'homepage_login_register', 'click_register', 'register for free')">
#                              <button class="btn btn-primary btn-yellow" type="button">Register for free</button>
#                          </a>
#                          <div class="sign_in pl-5 pt-4 ml-3">
#                              <a class="cls_register_signin_homepage cls_login_header cls_call_dialogbox" data-category="signin" data-from="header" data-popuptype="4" href="/myshine/login/" onclick="MyGA.SendEvent('homepage_login_register', 'homepage_login_register', 'click_signin', 'sign in')" title="Jobseeker Login">Sign in</a></div>
#                      </div>
#                  </div>
#              </section>
#              <div class="home_mid_open pt-4 cls_form cls_withform hide">
#                  <div class="d-flex pl-5 pr-5 justify-content-between">
#                      <div class="flex-column mt-1 pl-4 col-12">
#                          <h1 class="mb-3">Growth on your mind? <span class="close_form" id="id_hideform"></span></h1>
#
#                          <div class="hsearch d-flex flex-column flex-wrap">
#
#
#
#
#      <div class="advancsearch">
#         <form action="//www.shine.com/job-search/" class="cls_frm_reg_job_srch cls_txtanimation animation" data-errorcode="err_1" id="frm_adv_srch" method="post" novalidate="" onsubmit="common.stopBeforeJavascriptLoad(); searchAnalytics('frm_adv_srch', 'searchForm')">
#          <div class="cls_sel_serch_jobs cls_search_jobs search_left">
#              <ul>
#                  <li class="key Kjob">
#                      <label class="lbl">Job title, skills</label>
#                      <input aria-label="Job title,skills" class="cls_input_validate cls_local_autocomplete search3" data-rulesid="01" data-selecttype="multiple" id="id_q" maxlength="150" name="q" required="" tabindex="0" type="text"/>
#                  </li>
#                  <li class="key homepageloc"><label class="lbl">Location</label><input aria-label="Location" class="search3" id="id_loc" maxlength="150" name="loc" tabindex="0" type="text"/></li>
#                  <li class="key key1 kexp"><label class="lbl">Experience</label>
#                      <select aria-label="Experience" class="styled cls_minval" id="id_minexp" name="minexp">
#                              <option selected="" value="">Experience (Years)</option>
#                          </select>
#                  </li>
#              </ul>
#              <div class="clear"></div>
#              <ul class="floatleft cls_ulAdvSearch" id="adv_srch" style="display: none;">
#                  <li class="key key1 kexp1">
#                      <label class="lbl">Salary</label>
#                      <select aria-label="Salary" class="styled cls_minval" id="id_minsal" name="minsal">
#                              <option selected="" value="">Salary (Lakh/Year)</option>
#                          </select>
#                  </li>
#                  <li class="key key1 kexp1">
#                      <label class="lbl">Department</label>
#                      <select aria-label="Department" class="cls_input_validate styled" data-rulesid="01" id="id_area" name="area">
#                              <option selected="" value="">Department</option>
#                          </select>
#                  </li>
#                  <li class="key key1 kexp1" style="margin-right:none;"><label class="lbl">Industry</label>
#                      <select aria-label="Industry" class="cls_input_validate styled" data-rulesid="01" id="id_ind" name="ind">
#                              <option selected="" value="">Industry</option>
#                          </select></li>
#                  </ul>
#                  <li class="but1">
#                      <input id="id_head_trigger_advSrch" name="advSrch" type="hidden" value="false"/>
#                  </li>
#
#          </div>
#          <div class="expand" name="adv_srch">
#              <input aria-label="id_search_form" class="cls_btn_reg_job_srch cls_searchbtnabv submit" id="id_search_form" name="simplesearch" type="submit" value="Submit"/>
#              <a class="cls_ulAdvSearch_a" data-searchtype="adv_srch" href="javascript:void(0);">
#                  <u>Advanced search</u>
#              </a>
#           </div>
#         <input id="formmd5" name="formmd5" type="hidden" value=""/>
#          <input id="id_best_matches" name="best_matches" type="hidden" value=""/>
#          <input id="id_posted_after" name="posted_after" type="hidden" value=""/>
#         </form>
#      </div>
#  <!--
#  <input type="submit" value="" class="redbtn cls_btn_reg_job_srch_lrg" name="Submit" />
#  -->
#
#
#
#
#
#
#
#
#
#
#                          </div>
#                      </div>
#                  </div>
#              </div>
#              <!--cool places to work start-->
#
#              <div class="flex-column mt-2 col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#                  <h2 class="text-center">Cool places to work
#                  </h2>
#                  <ul class="cool d-flex flex-row mt-3 justify-content-around">
#
#                      <li class="p-3">
#                          <figure>
#
#                              <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=497070&amp;next=https://recruiter.shine.com/micro-site/aditya-birla-group-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Aditya Birla Management Corporation Pvt. Ltd.')" target="_blank">
#                                  <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/608a7830f65e4ac4a70869e145c55c25.png"/>
#                                  <span><img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/449660b6ea5c4aada2e211f4831cc945.png"/> </span>
#                              </a>
#
#                          </figure>
#                      </li>
#
#                      <li class="p-3">
#                          <figure>
#
#                              <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=654568&amp;next=https://www.shine.com/job-search/teleperformance-global-services-pvt-ltd-openings?rect=654568" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Teleperformance Global Services Pvt Ltd,')" target="_blank">
#                                  <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/d98a014b326648178fbb08eef46ac70e.png"/>
#                                  <span><img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6c23dfb3c9224480870c900b8dddf299.png"/> </span>
#                              </a>
#
#                          </figure>
#                      </li>
#
#                      <li class="p-3">
#                          <figure>
#
#                              <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=677780&amp;next=https://www.shine.com/job-search/sbi-life-insurance-company-limited-openings?rect=677780" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','SBI Life Insurance Company Limited')" target="_blank">
#                                  <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/7a22c70f27904e2e81d7ebd1066d55e1.png"/>
#                                  <span><img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/17e4d7d8d2bf419eb023429afacb5154.png"/> </span>
#                              </a>
#
#                          </figure>
#                      </li>
#
#                      <li class="p-3">
#                          <figure>
#
#                              <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=532598&amp;next=https://recruiter.shine.com/micro-site/infosys-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Infosys Limited')" target="_blank">
#                                  <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/26c83ce6d9df4733a9bbc06d2e3b8f0e.png"/>
#                                  <span><img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/19b43e6c9ee345faa75540f998db7441.png"/> </span>
#                              </a>
#
#                          </figure>
#                      </li>
#
#                      <li class="p-3">
#                          <figure>
#
#                              <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=55437&amp;next=https://recruiter.shine.com/micro-site/genpact-jobs/" onclick="MyGA.SendEvent('homepage_coolplaces','homepage_coolplaces','click_coolplaces','Genpact India Pvt Ltd')" target="_blank">
#                                  <img class="lozad img-fluid" data-src="https://static2.shine.com/r/m/images/employerbranding/c250bee50f5b490aac4b63fe281ab79e.png"/>
#                                  <span><img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/4ba34994bc414de7984c38c9cee86ebe.png"/> </span>
#                              </a>
#
#                          </figure>
#                      </li>
#
#                  </ul>
#              </div>
#
#              <!--cool places to work ends-->
#              <!--Top companies hiring starts-->
#              <div class="flex-column mt-4 mb-4 col-12 pl-xl-5 pr-xl-5 pl-lg-2 pr-lg-2">
#                  <h2 class="text-center pt-3">Top companies hiring now
#                  </h2>
#                  <ul class="top_employer d-flex flex-row mb-5 mt-3 flex-wrap">
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=700272&amp;next=https://www.shine.com/job-search/reliance-nippon-life-insurance-company-limited-openings?rect=700272" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','RELIANCE NIPPON LIFE INSURANCE COMPANY LIMITED')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/ab28f0af876f42cb96302faaea9e1671.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=699516&amp;next=https://recruiter.shine.com/micro-site/hewlett-packard-enterprise-jobs/" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Futurestep Recruitment Services Private Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/8ec12c71c03445248ec99942e16a812c.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=604202&amp;next=https://www.shine.com/job-search/yes-bank-ltd-openings?rect=604202" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Yes Bank Ltd')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/8b3d3868f9444657ad239ed43eb423b8.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=763688&amp;next=https://www.shine.com/job-search/tata-consultancy-services-limited-openings?rect=763688" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Tata Consultancy Services Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/b076fc83cebb42069205c9a410c9f618.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=735396&amp;next=https://www.shine.com/job-search/icici-bank-ltd-openings?rect=735396" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','ICICI Bank Ltd')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/9f53b7d4345d41ac9b657b726b6b3349.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=648608&amp;next=https://www.shine.com/job-search/aegis-customer-support-services-private-limited-openings?rect=648608" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Aegis Customer Support Services Private Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/da1f7501c8f740498dbb4b28fde081c2.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=700277&amp;next=https://www.shine.com/job-search/reliance-general-insurance-company-limited-openings?rect=700277" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','RELIANCE GENERAL INSURANCE COMPANY LIMITED')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/f85756b6a88e4997beaf87c6f1bb5cfd.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=641256&amp;next=https://www.shine.com/job-search/cms-it-services-private-limited-openings?rect=641256" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','CMS IT SERVICES PRIVATE LIMITED')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/f548e2c309c24db1a8b9d4ff9d97b02e.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=670803&amp;next=https://www.shine.com/job-search/tech-mahindra-ltd-openings?rect=670803" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Tech Mahindra Ltd.')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/a307d745fbbe46d3822e5b4e6f3fed55.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=683181&amp;next=https://www.shine.com/job-search/max-life-insurance-co-ltd-openings?rect=683181" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Max life insurance Co. LTD.')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6cf7d2611de84b7585d75db2f40e81b8.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=751515&amp;next=https://www.shine.com/job-search/d-mart-openings?rect=751515" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Avenue Supermarts Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/24d6c76bfae84a6f8bd18522f4744b3a.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=754750&amp;next=https://www.shine.com/job-search/byjus-openings?rect=754750" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','THINK &amp; LEARN PRIVATE LIMITED')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/9b944622fc46422786322e57d29a4225.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=709489&amp;next=https://www.shine.com/job-search/steria-jobs" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Steria (India) Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/666b83a3c4974b4f92613fce536a4251.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=677780&amp;next=https://www.shine.com/job-search/sbi-life-insurance-company-limited-openings?rect=677780" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','SBI Life Insurance Company Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/7f5bc2c5010f4e0fbff014205842ff27.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=736552&amp;next=https://recruiter.shine.com/micro-site/indegene-private-limited-jobs/" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Indegene Private Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/700cc0d27c8b416bbfb9c2765652c9cd.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=739959&amp;next=https://www.shine.com/job-search/anand-rathi-share-and-stock-brokers-limited-openings?rect=739959" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','ANAND RATHI SHARE AND STOCK BROKERS LIMITED')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/32ff5f1937b14c1d96212a1cfb563860.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=385010&amp;next=https://www.shine.com/job-search/quotes-kotak-mahindra-bank-limited-quotes-jobs?fcid=385010" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','Kotak Mahindra Bank Limited')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/264470edd81541d190bc774a279534aa.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
#                          <a href="https://www3.shine.com/click-tracking/?tracking_source=/&amp;tracking_drive=logo_tracking&amp;tracking_medium=web&amp;tracking_ID=101888&amp;next=https://www.shine.com/job-search/k12-techno-services-pvt-ltd-openings?rect=101888" onclick="MyGA.SendEvent('homepage_topcompanies','homepage_topcompanies','click_topcompanies','K12 Techno Services Pvt. Ltd')" target="_blank">
#                              <img class="lozad" data-src="https://static2.shine.com/r/m/images/employerbranding/6f1e554cc7fd4ab89210fb651db329ea.png"/>
#                          </a>
#
#                      </li>
#
#                      <li>
#
# ...
#                <i class="icon google"></i>
#              </div>
#              <div class="social-login--text google msite_displaynone">Apply with Google</div>
#            </div>
#          </li>
#
#          <li class="msite_displaynone">
#            <div class="social-login--btn facebook_button" data-actiontype="login" data-formtobesubmitted="id_applyWithFB" id="id_loginWithFB" onclick="MyGA.SendEvent('LoginPopup','facebook')">
#              <div class="social-login--icon">
#                <i class="icon facebook"></i>
#              </div>
#              <div class="social-login--text msite_displaynone">Apply with Facebook</div>
#            </div>
#          </li>
#        </ul>
#        <!----
#          Login with
#        -->
#        <ul class="cls_base_1 lgn_right lgn_right_linkedin social-login cls_social_login">
#
#          <li class="msite_displaynone socialLogin">
#            <div class="social-login--btn google_button customBtn" data-actiontype="login" data-formtobesubmitted="id_loginWithGoogle" id="gSignInWrapper" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','google')">
#              <div class="social-login--icon">
#                <i class="icon google"></i>
#              </div>
#              <div class="social-login--text google msite_displaynone">Sign-in with Google</div>
#            </div>
#          </li>
#
#
#          <li class="recentsearches msite_displaynone socialLogin">
#            <a class="social-login--btn linkedin_button" href="https://www.linkedin.com/oauth/v2/authorization?response_type=code&amp;client_id=757gbstpwa6dqp&amp;state=4c6f2cbf-675f-468e-bac0-9adc3048e5f3&amp;scope=r_emailaddress+r_basicprofile&amp;redirect_uri=https%3A%2F%2Fwww.shine.com%2Flinkedin%2Flogin" id="id_loginWithLinkedinUrl" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','Linkedin');">
#              <div class="social-login--icon">
#                <i class="icon linkedin"></i>
#              </div>
#              <div class="social-login--text msite_displaynone">Sign-in with Linkedin</div>
#            </a>
#          </li>
#
#
#          <li class="msite_displaynone">
#            <div class="social-login--btn facebook_button" data-actiontype="login" data-formtobesubmitted="id_loginWithFbForm" id="id_loginWithFB" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','facebook')">
#              <div class="social-login--icon">
#                <i class="icon facebook"></i>
#              </div>
#              <div class="social-login--text msite_displaynone">Sign-in with Facebook</div>
#            </div>
#          </li>
#
#          <!-- <li class="d-block text-center mt-4 regbtnText" style="width: 100%;">
#            Don't have Shine account?
#            <a href="/registration/parser/" class="white_button d-block col-7 mt-2 regBtn apply m-auto-temp"
#              onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','register now')"
#            >Register
#              now</a>
#          </li> -->
#        </ul>
#
#      <div class="cls_registernow register_bottom cls_base_1">
#            Don't have Shine account?
#            <a href="/registration/parser/" onclick="MyGA.SendEvent('signin_personal_social','signin_personal_social','click_login_social','register now')">Register
#              now</a>
#          </div>
#
#          <div class="clearfix"></div>
#      </div>
#    </div>
#  </div>
#  <div class="forget_password modal standard_form_class" id="id_candidateforgotpassword" style="display: none;">
#    <div class="overlay"></div>
#    <div class="modal_content">
#      <div class="modal_titlebar">
#        <span id="ui-id-1">Forget Password</span>
#        <a class="close" id="id_fpCancel">
#          <span class=""></span>
#        </a>
#      </div>
#      <div class="" id="id_candidateforgotpassword">
#        <div class="forget m-4" id="id_fPForm">
#          <span>Enter the Email ID with which you are registered on Shine.com</span>
#          <form action="javascript:void(0);" id="id_forgotPassword" method="POST" novalidate="novalidate" onsubmit="return false">
#            <ul>
#              <li>
#                <input aria-label="Email Id" id="candidateemailid" name="email" placeholder="Email" type="text"/>
#              </li>
#            </ul>
#          </form>
#        </div>
#        <div id="id_successMsg_fp" style="display: none; padding-left: 5%">
#            A link to reset your Shine Password has been sent to your Email Id
#        </div>
#      </div>
#
#      <div class="popup_button_pannel">
#        <button class="highlight_button" id="id_fpSubmit" type="button">Submit</button>
#        <button class="highlight_button" id="id_fpCancelButton" style="display: none;" type="button">Ok</button>
#      </div>
#
#    </div>
#  </div>
#      <script src="https://apis.google.com/js/api:client.js"></script>
#      <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js"></script>
#      <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.0.0/js/bootstrap.min.js"></script>
#      <script async="" defer="" src="https://accounts.google.com/gsi/client"></script>
#      <script src="https://static1.shine.com/c/s1/CACHE/js/9c4922e93e01.js" type="text/javascript"></script>
#      <script src="https://static1.shine.com/c/s1/CACHE/js/ab53d675170b.js" type="text/javascript"></script>
#  <script defer="" src="https://static1.shine.com/c/s1/CACHE/js/98179a304fa6.js" type="text/javascript"></script>
#      <script type="text/javascript">
#          $(document).ready(function () {
#              /* Page View Analytics Non Logged In */
#              // window.dapCollector('trackPageView', document.title);
#              let liveMintValue = "True";
#              if(liveMintValue == "True"){
#                  setTimeout(function(){window.dapCollector("trackImpression", "~", "vertical", 1, "Shine Homepage", "Livemint Homepage", "https://www.livemint.com/")},4000);
#              }
#              let elementVisited = true;
#              let timeInterval = setInterval(function(){
#                  var iframeElem = $('#div-gpt-ad-1404818223391-0 iframe');
#                  if(elementVisited && iframeElem[0]){
#                      iframeElem[0].contentWindow.document.body.onclick =
#                      function() {
#                      window.dapCollector("trackLinkClick", "https://www.livemint.com/", "Livemint Homepage");
#                      elementVisited = false;
#                      }
#                  }
#              }, 1000);
#              setTimeout(function(){
#                  clearInterval(timeInterval);
#              }, 8000);
#          });
#          $(window).scroll(function(){
#              // This is then function used to detect if the element is scrolled into view
#              function elementScrolled(elem)
#              {
#                  var docViewTop = $(window).scrollTop();
#                  var docViewBottom = docViewTop + $(window).height();
#                  if($(elem) && $(elem).length >0){
#                      var elemTop = $(elem).offset().top;
#                      return ((elemTop <= docViewBottom) && (elemTop >= docViewTop));
#                  }
#                  return false;
#              }
#
#              // This is where we use the function to detect if ".box2" is scrolled into view, and when it is add the class ".animated" to the <p> child element
#              if(elementScrolled('#id_course_carousel_ul_container')) {
#                  var productSession = common.getSessionStorage('productCustomEvent');
#                  if (productSession == null) {
#                      fireCustomEventArray();
#                      common.setSessionStorage("productCustomEvent", 1);
#                  }
#              }
#          });
#      </script>
#      <script src="https://static1.shine.com/c/s1/js/client/web/indexPage.js"></script>
#      <script src="//www.googleadservices.com/pagead/conversion.js"></script>
#      <noscript>
#          <div style="display:inline;">
#              <img alt="" class="lozad" data-src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1045809278/?value=0&amp;label=VNfsCJC81QMQ_pDX8gM&amp;guid=ON&amp;script=0" height="1" style="border-style:none;" width="1"/>
#          </div>
#      </noscript>
#
#
#      <!-- Google Tag Manager (noscript) -->
#      <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-TFD6PTW" style="display:none;visibility:hidden" width="0"></iframe></noscript>
#      <!-- End Google Tag Manager (noscript) -->
#
#
#      <script type="text/javascript">
#          $('.navbar-nav').on('mouseenter mouseleave', '.dropdown', function (e) {
#              var _d = $(e.target).closest('.dropdown');
#              if (e.type === 'mouseenter') _d.addClass('show');
#              setTimeout(function () {
#                  _d.toggleClass('show', _d.is(':hover'));
#                  $('[data-toggle="dropdown"]', _d).attr('aria-expanded', _d.is(':hover'));
#              }, 100);
#          });
#      </script>
#      <script>
#
#          $("#id_showform").on("click", function () {
#              $(".cls_withoutform").addClass('hide').removeClass("show");
#              $(".cls_withform").addClass('show').removeClass("hide");
#              $("#id_q").focus();
#              setTimeout(function () {
#                  $(".cls_search_jobs").addClass("show");
#              }, 10)
#          });
#          $("#id_hideform").on("click", function () {
#              $(".cls_withoutform").addClass('show').removeClass("hide");
#              $(".cls_withform").addClass('hide').removeClass("show");
#              $(".cls_search_jobs").removeClass("show");
#          });
#          lookupBinder.bindDropDown();
#          function fireCustomEventSingle(eventName,productName,productId,productPrice,productBrand,productCategory,productVariant,position,dimension1,dimension2,dimension3,actionField) {
#
#              arrayObject = [{
#                  name: productName,
#                  id: parseInt(productId, 10),
#                  price: productPrice,
#                  brand: productBrand,
#                  category: productCategory,
#                  variant: productVariant,
#                  position: parseInt(position, 10),
#                  dimension15: dimension1,
#                  dimension16: parseInt(dimension2, 10),
#                  dimension17: parseInt(dimension3, 10)
#              }]
#              try {
#                  window.dataLayer.push({
#                      event: eventName,
#                      ecommerce: {
#                          currencyCode: 'INR',
#                          click: {
#                              actionField: {
#                                  list: actionField
#                              },
#                              products: arrayObject
#                          }
#                      }
#                  });
#              } catch (e) {
#                  try {
#                      console.log(e);
#                  } catch (e) {}
#              }
#          }
#
#          function fireCustomEventArray() {
#              var data1 = [{'id': '3466', 'pHd': 'AI & Deep Learning with Tensor Flow', 'pURL': '/course/it-information-technology/ai-deep-learning-with-tensor-flow/pd-3466?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1549266081_7610.png', 'pBC': 9, 'pNJ': 10772, 'pPinb': 19995.0, 'pARx': '4.0', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '4317', 'pHd': 'AWS Architect Certification Training Combo', 'pURL': '/course/it-information-technology/aws-architect-certification-training-combo/pd-4317?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1564124425_1273.png', 'pBC': 21, 'pNJ': 44356, 'pPinb': 20995.0, 'pARx': '4.4', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '3416', 'pHd': 'Data Science with Python Certification Training Course', 'pURL': '/course/it-information-technology/data-science-with-python-certification-training-course/pd-3416?lc=1', 'pPvn': 'Edureka', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1541158456_9921.png', 'pBC': 63, 'pNJ': 66098, 'pPinb': 21995.0, 'pARx': '4.5', 'pCat': 'it-information-technology', 'recommendation_by': 'static'}, {'id': '4267', 'pHd': 'GST Practitioner Certification Course', 'pURL': '/course/banking-finance/gst-practitioner-certification-course/pd-4267?lc=1', 'pPvn': 'ISEL Global', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1561360226_4430.png', 'pBC': 385, 'pNJ': 12139, 'pPinb': 5700.0, 'pARx': '4.17', 'pCat': 'banking-finance', 'recommendation_by': 'static'}, {'id': '3394', 'pHd': 'Lean Six Sigma Expert Combo (GB + BB)', 'pURL': '/course/operation-management/lean-six-sigma-expert-combo-gb-bb/pd-3394?lc=1', 'pPvn': 'ISEL Global', 'pImg': 'https://static1.shine.com/l/m/product_image/images_all/1536737243_2955.png', 'pBC': 376, 'pNJ': 11405, 'pPinb': 21000.0, 'pARx': '4.72', 'pCat': 'operation-management', 'recommendation_by': 'static'}];
#              var arrayObject = [];
#              data1.map( (jsonObject, index) => {
#                  arrayObject.push({
#                      name: jsonObject.pHd,
#                      id: parseInt(jsonObject.id, 10),
#                      price: parseInt(jsonObject.pPinb, 10),
#                      brand: jsonObject.pPvn,
#                      category: jsonObject.pCat,
#                      variant: 'Product',
#                      position: parseInt(index + 1, 10),
#                      dimension15: 'Homepage-Shine.com',
#                      dimension16: parseInt(jsonObject.pBC, 10),
#                      dimension17: parseInt(jsonObject.pNJ, 10),
#                      list: 'Our best selling Courses'
#                  });
#              });
#              try {
#                  window.dataLayer.push({
#                      event: 'productImpression',
#                      ecommerce: {
#                          currencyCode: 'INR',
#                          impressions: arrayObject
#                      }
#                  });
#              } catch (e) {
#                  try {
#                      console.log(e);
#                  } catch (e) {}
#              }
#          }
#      </script>
#      <script>
#          var carouselFunction = new carouselFn();
#      </script>
#      <script>
#          document.getElementById('id_course_carousel_ul_container').childNodes.forEach((item)=>{
#          if(item.id){
#              let id = item.id
#              touchpointTrackingMap[id]= function () {
#                  /*
#                  *   code to access data attached to dom and call api
#                  */
#                  let touchPointElement = document.getElementById(item.id);
#                  let { tid, tracking: trackingData, position, subproducts, source } = touchPointElement.dataset;
#                  position = position ? parseInt(position) : 0; // considering 0 position as default position
#                  learningTouchPointsTrackingApi(tid, 9, subproducts, 'seen', position, trackingData, source, false);
#                  return true;
#              };
#          }
#      })
#      </script>
#      <script type="text/javascript">
#          $(document).ready(function(){
#              let randomAdsValue = Math.floor(Math.random() * 10) + 1;
#              if(randomAdsValue % 2 == 0){
#                  $('#id_banglore-banner').show();
#              }else {
#                  $('#id_hyderabad-banner').show();
#              }
#          })
#      </script>
#      <!-- Hotjar Tracking Code for https://www.shine.com/ -->
#      <script>
#          (function(h,o,t,j,a,r){
#              h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#              h._hjSettings={hjid:2630006,hjsv:6};
#              a=o.getElementsByTagName('head')[0];
#              r=o.createElement('script');r.async=1;
#              r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#              a.appendChild(r);
#          })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#      </script>
#
#
#  </body></html>]

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.Tag]

# %%
soup.select("div p")
# Out:
# [<p class="d-flex flex-column mt-2"><strong class="d-flex flex-column">3.4
#                                      crores+</strong><span class="d-flex flex-column">Candidates</span></p>,
#  <p class="d-flex flex-column mt-2"><strong class="d-flex flex-column">300,000+</strong><span class="d-flex flex-column">Jobs</span></p>,
#  <p class="d-flex flex-column mt-3"><strong class="d-flex flex-column">15,000+</strong><span class="d-flex flex-column">Companies</span></p>]
